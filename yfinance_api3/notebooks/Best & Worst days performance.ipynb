# %%
from yfinance_api3.classes.stock_client import StockClient
from yfinance_api3.classes.quant_analytics import QuantAnalytics as qa
import yfinance_api3.modules.plots as plots

# %%
client = StockClient(ttl_price=60, ttl_info=900)
quant = qa(client)

# %%
# main analysis table
df = quant.best_worst_days_impact("SPY", period="20y")
print(df[["scenario", "final_value", "total_return", "cagr"]].to_string())

# see exactly when the extreme days happened
detail = quant.best_worst_days_detail("SPY", period="20y", n=20)
print(detail)   # sorted best→worst, dates show they cluster around crises
# Out:
#               scenario   final_value  total_return      cagr
# 0           Buy & Hold  7.923112e+04      6.923112  0.109239
# 1     Miss best 5 days  4.735410e+04      3.735410  0.081006
# 2    Miss best 10 days  3.437977e+04      2.437977  0.063808
# 3    Miss best 20 days  2.067881e+04      1.067881  0.037061
# 4    Miss best 30 days  1.373354e+04      0.373354  0.016018
# 5    Miss best 40 days  9.566163e+03     -0.043384 -0.002219
# 6    Miss best 50 days  6.881912e+03     -0.311809 -0.018544
# 7    Miss worst 5 days  1.299063e+05     11.990629  0.137054
# 8   Miss worst 10 days  1.870210e+05     17.702102  0.157999
# 9   Miss worst 20 days  3.225210e+05     31.252104  0.190043
# 10  Miss worst 30 days  5.153589e+05     50.535889  0.218312
# 11  Miss worst 40 days  7.982851e+05     78.828513  0.245312
# 12  Miss worst 50 days  1.175408e+06    116.540760  0.269681
#            date    return   type
# rank
# 1    2008-10-13  0.145198   best
# 2    2008-10-28  0.116856   best
# 3    2025-04-09  0.105019   best
# 4    2020-03-24  0.090603   best
# 5    2020-03-13  0.085486   best
# 6    2009-03-23  0.071828   best
# 7    2008-11-24  0.069291   best
# 8    2020-04-06  0.067166   best
# 9    2008-11-13  0.062339   best
# 10   2008-10-20  0.060079   best
# 11   2009-03-10  0.059610   best
# 12   2020-03-26  0.058390   best
# 13   2022-11-10  0.054954   best
# 14   2020-03-17  0.053992   best
# 15   2008-11-21  0.053943   best
# 16   2020-03-10  0.051745   best
# 17   2018-12-26  0.050525   best
# 18   2008-12-16  0.047066   best
# 19   2011-08-09  0.046499   best
# 20   2011-08-11  0.044884   best
# 21   2025-04-03 -0.049281  worst
# 22   2008-11-14 -0.049907  worst
# 23   2020-03-18 -0.050633  worst
# 24   2008-10-24 -0.050715  worst
# 25   2008-10-06 -0.050933  worst
# 26   2009-01-20 -0.052786  worst
# 27   2008-10-22 -0.054455  worst
# 28   2008-11-06 -0.055411  worst
# 29   2020-06-11 -0.057649  worst
# 30   2025-04-04 -0.058543  worst
# 31   2008-11-19 -0.064079  worst
# 32   2011-08-08 -0.065123  worst
# 33   2008-10-09 -0.069838  worst
# 34   2008-11-20 -0.074233  worst
# 35   2020-03-09 -0.078095  worst
# 36   2008-09-29 -0.078362  worst
# 37   2008-12-01 -0.088578  worst
# 38   2020-03-12 -0.095677  worst
# 39   2008-10-15 -0.098448  worst
# 40   2020-03-16 -0.109424  worst

# %%
df
# Out:
#               scenario  days_missed   final_value  total_return      cagr  \
# 0           Buy & Hold            0  7.923112e+04      6.923112  0.109239
# 1     Miss best 5 days            5  4.735410e+04      3.735410  0.081006
# 2    Miss best 10 days           10  3.437977e+04      2.437977  0.063808
# 3    Miss best 20 days           20  2.067881e+04      1.067881  0.037061
# 4    Miss best 30 days           30  1.373354e+04      0.373354  0.016018
# 5    Miss best 40 days           40  9.566163e+03     -0.043384 -0.002219
# 6    Miss best 50 days           50  6.881912e+03     -0.311809 -0.018544
# 7    Miss worst 5 days            5  1.299063e+05     11.990629  0.137054
# 8   Miss worst 10 days           10  1.870210e+05     17.702102  0.157999
# 9   Miss worst 20 days           20  3.225210e+05     31.252104  0.190043
# 10  Miss worst 30 days           30  5.153589e+05     50.535889  0.218312
# 11  Miss worst 40 days           40  7.982851e+05     78.828513  0.245312
# 12  Miss worst 50 days           50  1.175408e+06    116.540760  0.269681
#
#      vs_buy_hold          type symbol period  n_trading_days  initial_value
# 0   0.000000e+00  buy_and_hold    SPY    20y            5031        10000.0
# 1  -3.187703e+04     miss_best    SPY    20y            5031        10000.0
# 2  -4.485136e+04     miss_best    SPY    20y            5031        10000.0
# 3  -5.855232e+04     miss_best    SPY    20y            5031        10000.0
# 4  -6.549759e+04     miss_best    SPY    20y            5031        10000.0
# 5  -6.966496e+04     miss_best    SPY    20y            5031        10000.0
# 6  -7.234921e+04     miss_best    SPY    20y            5031        10000.0
# 7   5.067517e+04    miss_worst    SPY    20y            5031        10000.0
# 8   1.077899e+05    miss_worst    SPY    20y            5031        10000.0
# 9   2.432899e+05    miss_worst    SPY    20y            5031        10000.0
# 10  4.361278e+05    miss_worst    SPY    20y            5031        10000.0
# 11  7.190540e+05    miss_worst    SPY    20y            5031        10000.0
# 12  1.096176e+06    miss_worst    SPY    20y            5031        10000.0

# %%
plots.best_worst_days(quant, "SPY", period="20y").show()

# custom scenarios
plots.best_worst_days(quant, "SPY",
                      miss_scenarios=[1, 5, 10, 20, 50],
                      initial_value=100_000).show()

# works for any stock/ETF
plots.best_worst_days(quant, "QQQ", period="20y").show()

# %% [markdown]
# ## Concentration of Good / Bad days

# %%
plots.extreme_days_concentration(quant, "SPY", period="20y").show()

# zoom in on fewer extreme days
plots.extreme_days_concentration(quant, "SPY", period="20y", n=20).show()

# shorter window for density (monthly instead of quarterly)
plots.extreme_days_concentration(quant, "SPY", n=50, window=21).show()
