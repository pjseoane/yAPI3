# %%
import yfinance_api3.modules.portfolio as portfolio

from yfinance_api3.classes.stock_client import StockClient
from yfinance_api3.classes.quant_analytics import QuantAnalytics as qa
import yfinance_api3.modules.plots as plots

client = StockClient(ttl_price=60, ttl_info=900)
quant = qa(client)

# %%
symbols = ["AAPL", "MSFT", "NVDA", "GOOGL", "JPM", "JNJ", "AMZN"]

# %%
ew  = portfolio.equal_weight(quant, symbols)
ew
# Out:
# PortfolioResult — Equal weight
#   Return     : 31.04%
#   Volatility : 18.34%
#   Sharpe     : 1.420
#   Weights:
#     AAPL: 14.29%
#     MSFT: 14.29%
#     NVDA: 14.29%
#     GOOGL: 14.29%
#     JPM: 14.29%
#     JNJ: 14.29%
#     AMZN: 14.29%

# %%
mv  = portfolio.min_variance(quant, symbols)
mv
# Out:
# PortfolioResult — Min variance
#   Return     : 19.11%
#   Volatility : 12.12%
#   Sharpe     : 1.164
#   Weights:
#     JNJ: 53.67%
#     MSFT: 19.19%
#     JPM: 13.12%
#     GOOGL: 5.75%
#     AAPL: 4.39%
#     AMZN: 2.16%
#     NVDA: 1.72%

# %%
ms  = portfolio.max_sharpe(quant, symbols)
ms
# Out:
# PortfolioResult — Max Sharpe
#   Return     : 31.62%
#   Volatility : 14.85%
#   Sharpe     : 1.792
#   Weights:
#     JNJ: 43.97%
#     JPM: 19.55%
#     GOOGL: 18.89%
#     NVDA: 17.59%
#     AMZN: 0.00%
#     MSFT: 0.00%
#     AAPL: 0.00%

# %%
rp  = portfolio.risk_parity(quant, symbols)

# %%
# compare all strategies in one table
df = portfolio.compare_strategies(quant, symbols)
print(df.to_string(float_format="{:.2%}".format))
# Out:
#               expected_return  volatility  sharpe_ratio   AAPL   MSFT   NVDA  GOOGL    JPM    JNJ   AMZN
# Equal weight           31.04%      18.34%       141.99% 14.29% 14.29% 14.29% 14.29% 14.29% 14.29% 14.29%
# Min variance           19.11%      12.12%       116.43%  4.39% 19.19%  1.72%  5.75% 13.12% 53.67%  2.16%
# Max Sharpe             31.62%      14.85%       179.24%  0.00%  0.00% 17.59% 18.89% 19.55% 43.97%  0.00%
# Risk parity            24.99%      13.82%       144.56% 11.42% 12.75%  7.11% 10.34% 14.41% 34.63%  9.34%

# %%
frontier = portfolio.efficient_frontier(quant, symbols, period="3y", n_points=60)
plots.efficient_frontier(frontier).show()

# %%
weights = ms.weights.tolist()
weights
# Out:
# [0.0,
#  0.0,
#  0.17589643911451444,
#  0.1888946338250237,
#  0.19550388193004808,
#  0.43970504513041425,
#  6.307010099681857e-17]

# %%
quant.portfolio_summary(symbols, weights, period="3y")
# Out:
# {'symbols': ['AAPL', 'MSFT', 'NVDA', 'GOOGL', 'JPM', 'JNJ', 'AMZN'],
#  'weights': [0.0,
#   0.0,
#   0.17589643911451444,
#   0.1888946338250237,
#   0.19550388193004808,
#   0.43970504513041425,
#   6.307010099681857e-17],
#  'period': '3y',
#  'annualised_return': 0.31618972630680175,
#  'annualised_volatility': 0.14850946707238125,
#  'sharpe_ratio': 1.7924091410082628,
#  'correlation_matrix': {'AAPL': {'AAPL': 1.0,
#    'MSFT': 0.4191238697242552,
#    'NVDA': 0.35620780892926107,
#    'GOOGL': 0.4303444681693105,
#    'JPM': 0.3158824892912351,
#    'JNJ': 0.04586937085358796,
#    'AMZN': 0.4355963370577864},
#   'MSFT': {'AAPL': 0.4191238697242552,
#    'MSFT': 1.0,
#    'NVDA': 0.5054689777638479,
#    'GOOGL': 0.42002548134265066,
#    'JPM': 0.2610234156249949,
#    'JNJ': -0.12650900869901224,
#    'AMZN': 0.552538284737735},
#   'NVDA': {'AAPL': 0.35620780892926107,
#    'MSFT': 0.5054689777638479,
#    'NVDA': 1.0,
#    'GOOGL': 0.4067483900289642,
#    'JPM': 0.2669081476354244,
#    'JNJ': -0.2489487125545288,
#    'AMZN': 0.4551847316025198},
#   'GOOGL': {'AAPL': 0.4303444681693105,
#    'MSFT': 0.42002548134265066,
#    'NVDA': 0.4067483900289642,
#    'GOOGL': 1.0,
#    'JPM': 0.2604791366054219,
#    'JNJ': -0.05723576009250944,
#    'AMZN': 0.5475827572157245},
#   'JPM': {'AAPL': 0.3158824892912351,
#    'MSFT': 0.2610234156249949,
#    'NVDA': 0.2669081476354244,
#    'GOOGL': 0.2604791366054219,
#    'JPM': 1.0,
#    'JNJ': 0.11535978751197778,
#    'AMZN': 0.3330390698884273},
#   'JNJ': {'AAPL': 0.04586937085358796,
#    'MSFT': -0.12650900869901224,
#    'NVDA': -0.2489487125545288,
#    'GOOGL': -0.05723576009250944,
#    'JPM': 0.11535978751197778,
#    'JNJ': 1.0,
#    'AMZN': -0.13977388702696414},
#   'AMZN': {'AAPL': 0.4355963370577864,
#    'MSFT': 0.552538284737735,
#    'NVDA': 0.4551847316025198,
#    'GOOGL': 0.5475827572157245,
#    'JPM': 0.3330390698884273,
#    'JNJ': -0.13977388702696414,
#    'AMZN': 1.0}}}
