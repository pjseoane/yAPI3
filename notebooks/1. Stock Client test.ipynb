# %% [markdown]
# # Stock Client Class

# %% [markdown]
# ## Imports

# %%
from yfinance_api3.classes.stock_client import StockClient

# %%
"""
TL settings (seconds)
    ----------------------
    ttl_price   : real-time / fast-changing data  (default  60 s)
    ttl_info    : company metadata                (default 600 s)
    ttl_history : historical OHLCV bars           (default 300 s)
    ttl_news    : news headlines                  (default 120 s)
"""
client = StockClient(ttl_price=60, ttl_info=900)

# %% [markdown]
# ## Class methods

# %%
# all public methods (no underscore)
[m for m in dir(client) if not m.startswith('_')]

# with signatures
import inspect

for name, method in inspect.getmembers(client, predicate=inspect.ismethod):
    if not name.startswith('_'):
        print(name, inspect.signature(method))
# Out:
# cache_stats () -> dict
# get_dividends (symbol: str) -> list[dict]
# get_financials (symbol: str) -> dict
# get_history (symbol: str, period: str = '1mo', interval: str = '1d', adjusted: bool = True) -> list[dict]
# get_info (symbol: str) -> dict
# get_news (symbol: str, limit: int = 10) -> list[dict]
# get_options_chain (symbol: str, expiry: str) -> dict
# get_options_expiries (symbol: str) -> list[str]
# get_price (symbol: str) -> dict
# get_price_change (symbol: str) -> dict
# get_prices_bulk (symbols: list[str]) -> dict[str, dict]
# get_recommendations (symbol: str) -> list[dict]
# get_summary (symbol: str) -> dict
# invalidate (symbol: str | None = None) -> int

# %%
#client.invalidate('AAPL')

# %%
client.get_summary('AAPL')
# Out:
# {'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'sector': 'Technology',
#  'industry': 'Consumer Electronics',
#  'country': 'United States',
#  'website': 'https://www.apple.com',
#  'fullTimeEmployees': 150000,
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple Vision Pro, Apple TV, Apple Watch, Beats products, and HomePod, as well as Apple branded and third-party accessories. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV, which offers exclusive original content and live sports; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers and resellers. The company was formerly known as Apple Computer, Inc. and changed its name to Apple Inc. in January 2007. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.',
#  'currency': 'USD'}

# %%
client.get_recommendations('AAPL')
# Out:
# [{'index': 0,
#   'period': '0m',
#   'strongBuy': 7,
#   'buy': 24,
#   'hold': 14,
#   'sell': 1,
#   'strongSell': 1},
#  {'index': 1,
#   'period': '-1m',
#   'strongBuy': 6,
#   'buy': 25,
#   'hold': 15,
#   'sell': 1,
#   'strongSell': 1},
#  {'index': 2,
#   'period': '-2m',
#   'strongBuy': 5,
#   'buy': 25,
#   'hold': 16,
#   'sell': 1,
#   'strongSell': 1},
#  {'index': 3,
#   'period': '-3m',
#   'strongBuy': 6,
#   'buy': 24,
#   'hold': 15,
#   'sell': 1,
#   'strongSell': 2}]

# %%
client.get_prices_bulk(['AAPL'])
# Out:
# {'AAPL': {'symbol': 'AAPL',
#   'price': 271.05999755859375,
#   'previous_close': 272.7,
#   'open': 272.760009765625,
#   'day_high': 273.05999755859375,
#   'day_low': 269.6499938964844,
#   'volume': 46026709,
#   'market_cap': 3979469772557.373,
#   'currency': 'USD',
#   'timestamp': '2026-04-26T02:44:11.397336+00:00'}}

# %%
client.get_price_change('AAPL')
# Out:
# {'symbol': 'AAPL',
#  'price': 271.05999755859375,
#  'previous_close': 272.7,
#  'change': -1.64,
#  'change_pct': -0.6014}

# %%
client.get_price('AAPL')
# Out:
# {'symbol': 'AAPL',
#  'price': 271.05999755859375,
#  'previous_close': 272.7,
#  'open': 272.760009765625,
#  'day_high': 273.05999755859375,
#  'day_low': 269.6499938964844,
#  'volume': 46026709,
#  'market_cap': 3979469772557.373,
#  'currency': 'USD',
#  'timestamp': '2026-04-26T02:44:11.397336+00:00'}

# %%
client.get_options_expiries('AAPL')
# Out:
# ['2026-04-27',
#  '2026-04-29',
#  '2026-05-01',
#  '2026-05-04',
#  '2026-05-08',
#  '2026-05-15',
#  '2026-05-22',
#  '2026-05-29',
#  '2026-06-18',
#  '2026-07-17',
#  '2026-08-21',
#  '2026-09-18',
#  '2026-10-16',
#  '2026-11-20',
#  '2026-12-18',
#  '2027-01-15',
#  '2027-03-19',
#  '2027-06-17',
#  '2027-12-17',
#  '2028-01-21',
#  '2028-03-17',
#  '2028-12-15']

# %%
client.get_options_chain('AAPL','2026-05-22')
# Out:
# {'calls': [{'contractSymbol': 'AAPL260522C00110000',
#    'lastTradeDate': Timestamp('2026-04-17 13:55:54+0000', tz='UTC'),
#    'strike': 110.0,
#    'lastPrice': 159.2,
#    'bid': 159.2,
#    'ask': 163.0,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': 1.0,
#    'openInterest': 4,
#    'impliedVolatility': 1.1757853710937498,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00170000',
#    'lastTradeDate': Timestamp('2026-04-15 13:36:54+0000', tz='UTC'),
#    'strike': 170.0,
#    'lastPrice': 90.5,
#    'bid': 99.35,
#    'ask': 103.15,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': nan,
#    'openInterest': 2,
#    'impliedVolatility': 0.762697685546875,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00190000',
#    'lastTradeDate': Timestamp('2026-04-07 13:53:34+0000', tz='UTC'),
#    'strike': 190.0,
#    'lastPrice': 60.95,
#    'bid': 79.55,
#    'ask': 83.1,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': nan,
#    'openInterest': 1,
#    'impliedVolatility': 0.6279334082031252,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00195000',
#    'lastTradeDate': Timestamp('2026-04-24 14:27:04+0000', tz='UTC'),
#    'strike': 195.0,
#    'lastPrice': 77.47,
#    'bid': 74.5,
#    'ask': 78.05,
#    'change': -1.1800003,
#    'percentChange': -1.5003182,
#    'volume': 1.0,
#    'openInterest': 2,
#    'impliedVolatility': 0.569340244140625,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00200000',
#    'lastTradeDate': Timestamp('2026-04-17 18:49:27+0000', tz='UTC'),
#    'strike': 200.0,
#    'lastPrice': 72.35,
#    'bid': 69.6,
#    'ask': 73.15,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': 4.0,
#    'openInterest': 4,
#    'impliedVolatility': 0.5629926513671876,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00205000',
#    'lastTradeDate': Timestamp('2026-04-02 17:23:53+0000', tz='UTC'),
#    'strike': 205.0,
#    'lastPrice': 51.51,
#    'bid': 64.6,
#    'ask': 68.2,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': 3.0,
#    'openInterest': 3,
#    'impliedVolatility': 0.5297898583984376,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00210000',
#    'lastTradeDate': Timestamp('2026-04-24 16:01:41+0000', tz='UTC'),
#    'strike': 210.0,
#    'lastPrice': 61.53,
#    'bid': 59.65,
#    'ask': 63.2,
#    'change': -1.3199997,
#    'percentChange': -2.1002383,
#    'volume': 1.0,
#    'openInterest': 6,
#    'impliedVolatility': 0.7230252307128906,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00215000',
#    'lastTradeDate': Timestamp('2026-04-23 15:45:08+0000', tz='UTC'),
#    'strike': 215.0,
#    'lastPrice': 59.06,
#    'bid': 54.75,
#    'ask': 58.3,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': 2.0,
#    'openInterest': 34,
#    'impliedVolatility': 0.6799348413085939,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00220000',
#    'lastTradeDate': Timestamp('2026-04-20 18:00:48+0000', tz='UTC'),
#    'strike': 220.0,
#    'lastPrice': 53.7,
#    'bid': 50.05,
#    'ask': 53.35,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': 1.0,
#    'openInterest': 23,
#    'impliedVolatility': 0.6325720336914062,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00225000',
#    'lastTradeDate': Timestamp('2026-04-24 19:45:22+0000', tz='UTC'),
#    'strike': 225.0,
#    'lastPrice': 46.5,
#    'bid': 45.3,
#    'ask': 48.4,
#    'change': -0.25999832,
#    'percentChange': -0.55602723,
#    'volume': 1.0,
#    'openInterest': 17,
#    'impliedVolatility': 0.5852092260742188,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00230000',
#    'lastTradeDate': Timestamp('2026-04-24 14:19:46+0000', tz='UTC'),
#    'strike': 230.0,
#    'lastPrice': 43.0,
#    'bid': 40.4,
#    'ask': 43.45,
#    'change': -1.2799988,
#    'percentChange': -2.890693,
#    'volume': 3.0,
#    'openInterest': 8,
#    'impliedVolatility': 0.5377243493652344,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00235000',
#    'lastTradeDate': Timestamp('2026-04-22 19:30:36+0000', tz='UTC'),
#    'strike': 235.0,
#    'lastPrice': 39.0,
#    'bid': 36.05,
#    'ask': 38.45,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': 4.0,
#    'openInterest': 38,
#    'impliedVolatility': 0.4866994689941406,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00240000',
#    'lastTradeDate': Timestamp('2026-04-23 19:35:56+0000', tz='UTC'),
#    'strike': 240.0,
#    'lastPrice': 35.6,
#    'bid': 31.8,
#    'ask': 33.55,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': 3.0,
#    'openInterest': 108,
#    'impliedVolatility': 0.4417780432128906,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00245000',
#    'lastTradeDate': Timestamp('2026-04-24 17:04:27+0000', tz='UTC'),
#    'strike': 245.0,
#    'lastPrice': 27.3,
#    'bid': 27.45,
#    'ask': 28.85,
#    'change': -2.2700005,
#    'percentChange': -7.676701,
#    'volume': 6.0,
#    'openInterest': 88,
#    'impliedVolatility': 0.4067442138671875,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00250000',
#    'lastTradeDate': Timestamp('2026-04-24 16:11:57+0000', tz='UTC'),
#    'strike': 250.0,
#    'lastPrice': 24.0,
#    'bid': 23.1,
#    'ask': 24.3,
#    'change': -1.8700008,
#    'percentChange': -7.2284527,
#    'volume': 3.0,
#    'openInterest': 317,
#    'impliedVolatility': 0.3754945263671875,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00255000',
#    'lastTradeDate': Timestamp('2026-04-24 19:31:25+0000', tz='UTC'),
#    'strike': 255.0,
#    'lastPrice': 18.72,
#    'bid': 18.95,
#    'ask': 20.1,
#    'change': -2.7399998,
#    'percentChange': -12.76794,
#    'volume': 40.0,
#    'openInterest': 287,
#    'impliedVolatility': 0.35425450439453116,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00260000',
#    'lastTradeDate': Timestamp('2026-04-24 19:31:25+0000', tz='UTC'),
#    'strike': 260.0,
#    'lastPrice': 14.93,
#    'bid': 15.2,
#    'ask': 15.85,
#    'change': -2.539999,
#    'percentChange': -14.539205,
#    'volume': 78.0,
#    'openInterest': 539,
#    'impliedVolatility': 0.32263860961914054,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00265000',
#    'lastTradeDate': Timestamp('2026-04-24 19:54:29+0000', tz='UTC'),
#    'strike': 265.0,
#    'lastPrice': 12.35,
#    'bid': 11.85,
#    'ask': 12.4,
#    'change': -2.29,
#    'percentChange': -15.642076,
#    'volume': 63.0,
#    'openInterest': 673,
#    'impliedVolatility': 0.3112251495361328,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00270000',
#    'lastTradeDate': Timestamp('2026-04-24 19:59:57+0000', tz='UTC'),
#    'strike': 270.0,
#    'lastPrice': 9.0,
#    'bid': 8.85,
#    'ask': 9.2,
#    'change': -1.6000004,
#    'percentChange': -15.094343,
#    'volume': 764.0,
#    'openInterest': 1073,
#    'impliedVolatility': 0.29505099487304687,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00275000',
#    'lastTradeDate': Timestamp('2026-04-24 19:59:57+0000', tz='UTC'),
#    'strike': 275.0,
#    'lastPrice': 6.55,
#    'bid': 6.3,
#    'ask': 6.7,
#    'change': -1.4499998,
#    'percentChange': -18.124998,
#    'volume': 780.0,
#    'openInterest': 1258,
#    'impliedVolatility': 0.28784891845703114,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00280000',
#    'lastTradeDate': Timestamp('2026-04-24 19:59:46+0000', tz='UTC'),
#    'strike': 280.0,
#    'lastPrice': 4.6,
#    'bid': 4.5,
#    'ask': 4.7,
#    'change': -1.0,
#    'percentChange': -17.857143,
#    'volume': 1298.0,
#    'openInterest': 5110,
#    'impliedVolatility': 0.2819285675048828,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00285000',
#    'lastTradeDate': Timestamp('2026-04-24 19:59:57+0000', tz='UTC'),
#    'strike': 285.0,
#    'lastPrice': 3.1,
#    'bid': 3.0,
#    'ask': 3.2,
#    'change': -0.70000005,
#    'percentChange': -18.421055,
#    'volume': 214.0,
#    'openInterest': 4071,
#    'impliedVolatility': 0.27826649475097653,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00290000',
#    'lastTradeDate': Timestamp('2026-04-24 19:54:05+0000', tz='UTC'),
#    'strike': 290.0,
#    'lastPrice': 2.16,
#    'bid': 2.01,
#    'ask': 2.17,
#    'change': -0.66999984,
#    'percentChange': -23.674908,
#    'volume': 1934.0,
#    'openInterest': 2883,
#    'impliedVolatility': 0.27875477111816405,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00295000',
#    'lastTradeDate': Timestamp('2026-04-24 19:59:43+0000', tz='UTC'),
#    'strike': 295.0,
#    'lastPrice': 1.4,
#    'bid': 1.32,
#    'ask': 1.43,
#    'change': -0.46000004,
#    'percentChange': -24.731184,
#    'volume': 213.0,
#    'openInterest': 2045,
#    'impliedVolatility': 0.2791820129394531,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00300000',
#    'lastTradeDate': Timestamp('2026-04-24 19:56:46+0000', tz='UTC'),
#    'strike': 300.0,
#    'lastPrice': 0.9,
#    'bid': 0.86,
#    'ask': 0.92,
#    'change': -0.22000003,
#    'percentChange': -19.64286,
#    'volume': 377.0,
#    'openInterest': 1192,
#    'impliedVolatility': 0.2797923583984374,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00305000',
#    'lastTradeDate': Timestamp('2026-04-24 19:45:47+0000', tz='UTC'),
#    'strike': 305.0,
#    'lastPrice': 0.58,
#    'bid': 0.55,
#    'ask': 0.64,
#    'change': -0.21000004,
#    'percentChange': -26.582283,
#    'volume': 480.0,
#    'openInterest': 368,
#    'impliedVolatility': 0.2868723657226562,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00310000',
#    'lastTradeDate': Timestamp('2026-04-24 19:28:12+0000', tz='UTC'),
#    'strike': 310.0,
#    'lastPrice': 0.39,
#    'bid': 0.36,
#    'ask': 0.43,
#    'change': -0.100000024,
#    'percentChange': -20.408169,
#    'volume': 911.0,
#    'openInterest': 409,
#    'impliedVolatility': 0.29175512939453113,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00315000',
#    'lastTradeDate': Timestamp('2026-04-24 19:22:26+0000', tz='UTC'),
#    'strike': 315.0,
#    'lastPrice': 0.27,
#    'bid': 0.23,
#    'ask': 0.29,
#    'change': -0.00999999,
#    'percentChange': -3.571425,
#    'volume': 183.0,
#    'openInterest': 173,
#    'impliedVolatility': 0.2971261694335937,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00320000',
#    'lastTradeDate': Timestamp('2026-04-24 17:07:23+0000', tz='UTC'),
#    'strike': 320.0,
#    'lastPrice': 0.16,
#    'bid': 0.14,
#    'ask': 0.21,
#    'change': -0.040000007,
#    'percentChange': -20.000004,
#    'volume': 27.0,
#    'openInterest': 139,
#    'impliedVolatility': 0.305671005859375,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00325000',
#    'lastTradeDate': Timestamp('2026-04-22 19:33:23+0000', tz='UTC'),
#    'strike': 325.0,
#    'lastPrice': 0.15,
#    'bid': 0.07,
#    'ask': 0.17,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': 13.0,
#    'openInterest': 27,
#    'impliedVolatility': 0.3188544677734374,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00330000',
#    'lastTradeDate': Timestamp('2026-04-24 19:16:42+0000', tz='UTC'),
#    'strike': 330.0,
#    'lastPrice': 0.06,
#    'bid': 0.05,
#    'ask': 0.11,
#    'change': -0.08,
#    'percentChange': -57.142853,
#    'volume': 2.0,
#    'openInterest': 155,
#    'impliedVolatility': 0.32129584960937496,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00335000',
#    'lastTradeDate': Timestamp('2026-04-24 13:52:51+0000', tz='UTC'),
#    'strike': 335.0,
#    'lastPrice': 0.07,
#    'bid': 0.03,
#    'ask': 0.09,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': 5.0,
#    'openInterest': 14,
#    'impliedVolatility': 0.33301448242187504,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00340000',
#    'lastTradeDate': Timestamp('2026-04-23 13:50:41+0000', tz='UTC'),
#    'strike': 340.0,
#    'lastPrice': 0.04,
#    'bid': 0.02,
#    'ask': 0.07,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': 1.0,
#    'openInterest': 29,
#    'impliedVolatility': 0.34278000976562495,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00345000',
#    'lastTradeDate': Timestamp('2026-04-24 19:16:42+0000', tz='UTC'),
#    'strike': 345.0,
#    'lastPrice': 0.04,
#    'bid': 0.01,
#    'ask': 0.07,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': 2.0,
#    'openInterest': 11,
#    'impliedVolatility': 0.36133451171875,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00350000',
#    'lastTradeDate': Timestamp('2026-04-24 16:47:20+0000', tz='UTC'),
#    'strike': 350.0,
#    'lastPrice': 0.11,
#    'bid': 0.01,
#    'ask': 0.19,
#    'change': 0.05,
#    'percentChange': 83.333336,
#    'volume': 1.0,
#    'openInterest': 4,
#    'impliedVolatility': 0.4321345849609375,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522C00375000',
#    'lastTradeDate': Timestamp('2026-04-17 16:57:01+0000', tz='UTC'),
#    'strike': 375.0,
#    'lastPrice': 0.02,
#    'bid': 0.0,
#    'ask': 0.5,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': 2.0,
#    'openInterest': 0,
#    'impliedVolatility': 0.5488326367187502,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'}],
#  'puts': [{'contractSymbol': 'AAPL260522P00110000',
#    'lastTradeDate': Timestamp('2026-04-24 19:55:01+0000', tz='UTC'),
#    'strike': 110.0,
#    'lastPrice': 0.01,
#    'bid': 0.01,
#    'ask': 0.29,
#    'change': -0.19,
#    'percentChange': -95.0,
#    'volume': 15.0,
#    'openInterest': 8,
#    'impliedVolatility': 1.3574250878906249,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00130000',
#    'lastTradeDate': Timestamp('2026-04-24 16:26:47+0000', tz='UTC'),
#    'strike': 130.0,
#    'lastPrice': 0.04,
#    'bid': 0.01,
#    'ask': 0.15,
#    'change': -0.13,
#    'percentChange': -76.47058,
#    'volume': 8.0,
#    'openInterest': 67,
#    'impliedVolatility': 1.0429735351562504,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00135000',
#    'lastTradeDate': Timestamp('2026-04-24 19:38:14+0000', tz='UTC'),
#    'strike': 135.0,
#    'lastPrice': 0.22,
#    'bid': 0.01,
#    'ask': 0.5,
#    'change': -0.010000005,
#    'percentChange': -4.3478284,
#    'volume': 1.0,
#    'openInterest': 48,
#    'impliedVolatility': 1.142582412109375,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00140000',
#    'lastTradeDate': Timestamp('2026-04-24 14:47:54+0000', tz='UTC'),
#    'strike': 140.0,
#    'lastPrice': 0.02,
#    'bid': 0.01,
#    'ask': 0.11,
#    'change': -0.099999994,
#    'percentChange': -83.33333,
#    'volume': 24.0,
#    'openInterest': 67,
#    'impliedVolatility': 0.9179695703125,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00145000',
#    'lastTradeDate': Timestamp('2026-04-24 14:58:47+0000', tz='UTC'),
#    'strike': 145.0,
#    'lastPrice': 0.12,
#    'bid': 0.01,
#    'ask': 0.28,
#    'change': -0.089999996,
#    'percentChange': -42.857143,
#    'volume': 18.0,
#    'openInterest': 30,
#    'impliedVolatility': 0.96289099609375,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00150000',
#    'lastTradeDate': Timestamp('2026-04-24 14:44:37+0000', tz='UTC'),
#    'strike': 150.0,
#    'lastPrice': 0.03,
#    'bid': 0.01,
#    'ask': 0.33,
#    'change': -0.2,
#    'percentChange': -86.95652,
#    'volume': 20.0,
#    'openInterest': 45,
#    'impliedVolatility': 0.9335944140625,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00160000',
#    'lastTradeDate': Timestamp('2026-04-16 15:09:27+0000', tz='UTC'),
#    'strike': 160.0,
#    'lastPrice': 0.06,
#    'bid': 0.0,
#    'ask': 0.48,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': nan,
#    'openInterest': 5,
#    'impliedVolatility': 0.8798840136718749,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00170000',
#    'lastTradeDate': Timestamp('2026-04-23 17:35:27+0000', tz='UTC'),
#    'strike': 170.0,
#    'lastPrice': 0.05,
#    'bid': 0.0,
#    'ask': 0.23,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': 3.0,
#    'openInterest': 5,
#    'impliedVolatility': 0.71679970703125,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00175000',
#    'lastTradeDate': Timestamp('2026-04-24 16:03:38+0000', tz='UTC'),
#    'strike': 175.0,
#    'lastPrice': 0.04,
#    'bid': 0.0,
#    'ask': 0.29,
#    'change': -0.060000002,
#    'percentChange': -60.000004,
#    'volume': 3.0,
#    'openInterest': 2,
#    'impliedVolatility': 0.6953155468750001,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00180000',
#    'lastTradeDate': Timestamp('2026-04-23 19:16:05+0000', tz='UTC'),
#    'strike': 180.0,
#    'lastPrice': 0.04,
#    'bid': 0.01,
#    'ask': 0.08,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': 3.0,
#    'openInterest': 190,
#    'impliedVolatility': 0.570316796875,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00185000',
#    'lastTradeDate': Timestamp('2026-04-24 15:59:52+0000', tz='UTC'),
#    'strike': 185.0,
#    'lastPrice': 0.04,
#    'bid': 0.03,
#    'ask': 0.09,
#    'change': -0.02,
#    'percentChange': -33.333336,
#    'volume': 3.0,
#    'openInterest': 191,
#    'impliedVolatility': 0.55273884765625,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00190000',
#    'lastTradeDate': Timestamp('2026-04-24 19:08:13+0000', tz='UTC'),
#    'strike': 190.0,
#    'lastPrice': 0.09,
#    'bid': 0.04,
#    'ask': 0.09,
#    'change': 0.030000005,
#    'percentChange': 50.00001,
#    'volume': 15.0,
#    'openInterest': 117,
#    'impliedVolatility': 0.523442265625,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00195000',
#    'lastTradeDate': Timestamp('2026-04-24 19:11:16+0000', tz='UTC'),
#    'strike': 195.0,
#    'lastPrice': 0.11,
#    'bid': 0.05,
#    'ask': 0.12,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': 8.0,
#    'openInterest': 148,
#    'impliedVolatility': 0.5039112109375,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00200000',
#    'lastTradeDate': Timestamp('2026-04-24 18:30:42+0000', tz='UTC'),
#    'strike': 200.0,
#    'lastPrice': 0.12,
#    'bid': 0.09,
#    'ask': 0.12,
#    'change': -0.020000003,
#    'percentChange': -14.285716,
#    'volume': 10029.0,
#    'openInterest': 10669,
#    'impliedVolatility': 0.49023947265625006,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00205000',
#    'lastTradeDate': Timestamp('2026-04-23 17:07:31+0000', tz='UTC'),
#    'strike': 205.0,
#    'lastPrice': 0.16,
#    'bid': 0.09,
#    'ask': 0.21,
#    'change': 0.0,
#    'percentChange': 0.0,
#    'volume': 59.0,
#    'openInterest': 172,
#    'impliedVolatility': 0.49170430175781255,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00210000',
#    'lastTradeDate': Timestamp('2026-04-24 17:43:07+0000', tz='UTC'),
#    'strike': 210.0,
#    'lastPrice': 0.19,
#    'bid': 0.13,
#    'ask': 0.24,
#    'change': -0.019999996,
#    'percentChange': -9.523808,
#    'volume': 24.0,
#    'openInterest': 171,
#    'impliedVolatility': 0.463872548828125,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00215000',
#    'lastTradeDate': Timestamp('2026-04-24 19:44:18+0000', tz='UTC'),
#    'strike': 215.0,
#    'lastPrice': 0.3,
#    'bid': 0.13,
#    'ask': 0.28,
#    'change': 0.07000001,
#    'percentChange': 30.434784,
#    'volume': 89.0,
#    'openInterest': 347,
#    'impliedVolatility': 0.437505625,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00220000',
#    'lastTradeDate': Timestamp('2026-04-24 19:50:26+0000', tz='UTC'),
#    'strike': 220.0,
#    'lastPrice': 0.32,
#    'bid': 0.29,
#    'ask': 0.36,
#    'change': 0.00999999,
#    'percentChange': 3.2258034,
#    'volume': 98.0,
#    'openInterest': 275,
#    'impliedVolatility': 0.4177304321289062,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00225000',
#    'lastTradeDate': Timestamp('2026-04-24 19:59:48+0000', tz='UTC'),
#    'strike': 225.0,
#    'lastPrice': 0.45,
#    'bid': 0.39,
#    'ask': 0.45,
#    'change': 0.00999999,
#    'percentChange': 2.272725,
#    'volume': 119.0,
#    'openInterest': 328,
#    'impliedVolatility': 0.39551385742187506,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00230000',
#    'lastTradeDate': Timestamp('2026-04-24 19:31:12+0000', tz='UTC'),
#    'strike': 230.0,
#    'lastPrice': 0.59,
#    'bid': 0.53,
#    'ask': 0.63,
#    'change': 0.07999998,
#    'percentChange': 15.686272,
#    'volume': 45.0,
#    'openInterest': 400,
#    'impliedVolatility': 0.3820862573242187,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00235000',
#    'lastTradeDate': Timestamp('2026-04-24 19:56:46+0000', tz='UTC'),
#    'strike': 235.0,
#    'lastPrice': 0.81,
#    'bid': 0.74,
#    'ask': 0.84,
#    'change': 0.089999974,
#    'percentChange': 12.499995,
#    'volume': 68.0,
#    'openInterest': 513,
#    'impliedVolatility': 0.36463037719726565,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00240000',
#    'lastTradeDate': Timestamp('2026-04-24 19:45:47+0000', tz='UTC'),
#    'strike': 240.0,
#    'lastPrice': 1.13,
#    'bid': 1.0,
#    'ask': 1.11,
#    'change': 0.19999999,
#    'percentChange': 21.505375,
#    'volume': 159.0,
#    'openInterest': 692,
#    'impliedVolatility': 0.3461979443359374,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00245000',
#    'lastTradeDate': Timestamp('2026-04-24 19:58:33+0000', tz='UTC'),
#    'strike': 245.0,
#    'lastPrice': 1.46,
#    'bid': 1.4,
#    'ask': 1.52,
#    'change': 0.18000007,
#    'percentChange': 14.062506,
#    'volume': 133.0,
#    'openInterest': 588,
#    'impliedVolatility': 0.3309393078613281,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00250000',
#    'lastTradeDate': Timestamp('2026-04-24 19:58:26+0000', tz='UTC'),
#    'strike': 250.0,
#    'lastPrice': 2.01,
#    'bid': 2.0,
#    'ask': 2.19,
#    'change': 0.27999997,
#    'percentChange': 16.184969,
#    'volume': 128.0,
#    'openInterest': 653,
#    'impliedVolatility': 0.3219061950683593,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00255000',
#    'lastTradeDate': Timestamp('2026-04-24 19:53:41+0000', tz='UTC'),
#    'strike': 255.0,
#    'lastPrice': 2.85,
#    'bid': 2.78,
#    'ask': 2.95,
#    'change': 0.3499999,
#    'percentChange': 13.999995,
#    'volume': 269.0,
#    'openInterest': 571,
#    'impliedVolatility': 0.3060372131347656,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00260000',
#    'lastTradeDate': Timestamp('2026-04-24 19:57:25+0000', tz='UTC'),
#    'strike': 260.0,
#    'lastPrice': 3.93,
#    'bid': 3.85,
#    'ask': 4.1,
#    'change': 0.43000007,
#    'percentChange': 12.285716,
#    'volume': 124.0,
#    'openInterest': 313,
#    'impliedVolatility': 0.2955392712402344,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00265000',
#    'lastTradeDate': Timestamp('2026-04-24 19:53:10+0000', tz='UTC'),
#    'strike': 265.0,
#    'lastPrice': 5.6,
#    'bid': 5.45,
#    'ask': 5.65,
#    'change': 0.7999997,
#    'percentChange': 16.66666,
#    'volume': 98.0,
#    'openInterest': 771,
#    'impliedVolatility': 0.2866282275390625,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00270000',
#    'lastTradeDate': Timestamp('2026-04-24 19:53:41+0000', tz='UTC'),
#    'strike': 270.0,
#    'lastPrice': 7.49,
#    'bid': 7.4,
#    'ask': 7.65,
#    'change': 1.06,
#    'percentChange': 16.485224,
#    'volume': 190.0,
#    'openInterest': 581,
#    'impliedVolatility': 0.27838856384277344,
#    'inTheMoney': False,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00275000',
#    'lastTradeDate': Timestamp('2026-04-24 19:49:32+0000', tz='UTC'),
#    'strike': 275.0,
#    'lastPrice': 10.31,
#    'bid': 9.9,
#    'ask': 10.25,
#    'change': 1.3900003,
#    'percentChange': 15.582964,
#    'volume': 170.0,
#    'openInterest': 258,
#    'impliedVolatility': 0.27448235290527345,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00280000',
#    'lastTradeDate': Timestamp('2026-04-24 19:51:30+0000', tz='UTC'),
#    'strike': 280.0,
#    'lastPrice': 13.15,
#    'bid': 12.2,
#    'ask': 13.4,
#    'change': 1.5699997,
#    'percentChange': 13.557856,
#    'volume': 143.0,
#    'openInterest': 176,
#    'impliedVolatility': 0.2732006274414062,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00285000',
#    'lastTradeDate': Timestamp('2026-04-24 18:03:29+0000', tz='UTC'),
#    'strike': 285.0,
#    'lastPrice': 17.32,
#    'bid': 14.9,
#    'ask': 18.55,
#    'change': 2.6899996,
#    'percentChange': 18.386873,
#    'volume': 1.0,
#    'openInterest': 4,
#    'impliedVolatility': 0.3345403460693359,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00290000',
#    'lastTradeDate': Timestamp('2026-04-24 14:57:12+0000', tz='UTC'),
#    'strike': 290.0,
#    'lastPrice': 20.05,
#    'bid': 19.15,
#    'ask': 22.65,
#    'change': -0.95000076,
#    'percentChange': -4.523813,
#    'volume': 10.0,
#    'openInterest': 14,
#    'impliedVolatility': 0.34839518798828123,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'},
#   {'contractSymbol': 'AAPL260522P00300000',
#    'lastTradeDate': Timestamp('2026-04-24 13:59:40+0000', tz='UTC'),
#    'strike': 300.0,
#    'lastPrice': 29.05,
#    'bid': 27.9,
#    'ask': 31.5,
#    'change': 0.25,
#    'percentChange': 0.8680556,
#    'volume': 1.0,
#    'openInterest': 6,
#    'impliedVolatility': 0.3811097045898437,
#    'inTheMoney': True,
#    'contractSize': 'REGULAR',
#    'currency': 'USD'}]}

# %%
client.get_news('AAPL', limit=10)
# Out:
# [{'title': 'Dow Jones Futures: Iran Talks Off; Apple, Amazon, Google Lead Earnings Wave',
#   'summary': 'The stock market is at highs but results and spending for Apple, Amazon, Google and more will be key. Iran talks were called off.',
#   'url': 'https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-apple-amazon-google-earnings-ai-iran-talks/?src=A00220&yptr=yahoo',
#   'publisher': "Investor's Business Daily",
#   'published_at': '2026-04-26T00:08:31Z'},
#  {'title': 'A Look At Skyworks Solutions (SWKS) Valuation After Barclays Upgrade And Apple Device Delay',
#   'summary': 'Analyst upgrade and Apple timing shift move Skyworks Solutions (SWKS) Skyworks Solutions (SWKS) shares climbed after Barclays upgraded the stock, noting expectations that a delay in new low end Apple devices could extend demand for Skyworks components in current iPhone models. See our latest analysis for Skyworks Solutions. Beyond the upgrade, the stock has been rebuilding momentum, with a 1 month share price return of 13.28% and a 1 year total shareholder return of 7.97%, although the 5 year...',
#   'url': 'https://finance.yahoo.com/markets/stocks/articles/look-skyworks-solutions-swks-valuation-170510668.html',
#   'publisher': 'Simply Wall St.',
#   'published_at': '2026-04-25T17:05:10Z'},
#  {'title': 'The Highest-Paid CEO Is a Furniture Salesman',
#   'summary': 'The median annual pay of large company CEOs hit $29.4 million last year, a record high, up 23.2%. It’s still one big fat guessing game.',
#   'url': 'https://www.barrons.com/articles/ceo-pay-apple-adobe-wayfair-d72581df?siteid=yhoof2&yptr=yahoo',
#   'publisher': 'Barrons.com',
#   'published_at': '2026-04-25T15:18:00Z'},
#  {'title': 'Goldman Sachs reassesses Apple stock ahead of earnings',
#   'summary': "Apple is heading into its April 30 earnings report, with investors focused on iPhone demand, outlooks, and what’s next for its AI strategy under its upcoming new CEO. The iPhone maker's stock has lagged this year, down about 0.64% year to date compared with a 4.67% gain for the S&P 500 index, ...",
#   'url': 'https://www.thestreet.com/investing/stocks/goldman-sachs-reassesses-apple-stock-ahead-of-earnings',
#   'publisher': 'TheStreet',
#   'published_at': '2026-04-25T14:07:00Z'},
#  {'title': 'Upcoming Foldable iPhones Make These 2 Chip Stocks a Buy Now, According to Barclays',
#   'summary': 'As Apple inches toward foldable iPhones, Barclays is turning to chipmakers like Skyworks Solutions and Qorvo, seeing an opportunity to buy these stocks at attractive levels.',
#   'url': 'https://www.barchart.com/story/news/1517191/upcoming-foldable-iphones-make-these-2-chip-stocks-a-buy-now-according-to-barclays',
#   'publisher': 'Barchart',
#   'published_at': '2026-04-25T13:00:02Z'},
#  {'title': 'Stock Market Week Ahead: Hyperscaler Blitz, Federal Reserve Transition',
#   'summary': 'The stock market brims with optimism ahead of a huge surge of AI hyperscaler earnings, amid an historical transition at the Federal Reserve.',
#   'url': 'https://www.investors.com/research/investing-action-plan/stock-market-week-hyperscalers-federal-reserve-warsh-powell-apple-amazon-google/?src=A00220&yptr=yahoo',
#   'publisher': "Investor's Business Daily",
#   'published_at': '2026-04-25T10:30:58Z'},
#  {'title': 'Alphabet Next: Google Cloud Says 75% of Customers Use AI as Pichai Targets $175B-$185B CapEx',
#   'summary': 'Google Cloud used its Next conference to highlight what CEO Thomas Kurian described as a shift from experimentation to scaled deployment of artificial intelligence, telling attendees that “nearly 75% of Google Cloud customers now leverage our AI products to power their businesses.” Kurian said the f',
#   'url': 'https://www.marketbeat.com/instant-alerts/alphabet-next-google-cloud-says-75-of-customers-use-ai-as-pichai-targets-175b-185b-capex-2026-04-25/?utm_source=yahoofinance&utm_medium=yahoofinance',
#   'publisher': 'MarketBeat',
#   'published_at': '2026-04-25T06:03:10Z'},
#  {'title': 'Apple Inc. (AAPL) Appointed John Ternus as CEO',
#   'summary': 'Apple Inc. (NASDAQ:AAPL) is one of the 8 Best AI Stocks to Buy According to Billionaire Ken Griffin. On April 21, Reuters reported that Apple Inc. (NASDAQ:AAPL) appointed John Ternus as CEO, showing a renewed focus on hardware and adding AI to existing devices rather than introducing a specific AI product. Ternus, a 25-year veteran […]',
#   'url': 'https://finance.yahoo.com/markets/stocks/articles/apple-inc-aapl-appointed-john-055723359.html',
#   'publisher': 'Insider Monkey',
#   'published_at': '2026-04-25T05:57:23Z'},
#  {'title': "Apple, Amazon, Others Not Seeking Tariff Refunds To Avoid Offending Trump? The President Says He'll 'Remember' Them",
#   'summary': 'President Donald Trump weighed in as major corporations, including Apple Inc. and Amazon Inc., reportedly avoided seeking tariff reimbursements. According to CNBC’s Andrew Ross Sorkin, several major companies opting not to claim tariff refunds may reflect a desire to avoid “offending” Trump and possibly to sidestep political backlash. When he asked about the issue during an interview on Tuesday, Trump said, “I think it’s brilliant if they don’t do that, if they don’t do that, they got to know me',
#   'url': 'https://finance.yahoo.com/economy/policy/articles/apple-amazon-others-not-seeking-003120459.html',
#   'publisher': 'Benzinga',
#   'published_at': '2026-04-25T00:31:20Z'},
#  {'title': 'Review & Preview: Dot-Com Glory Days',
#   'summary': 'Intel soared 24% to its first record close since August 2000. The rally says everything you need to know about today’s market.',
#   'url': 'https://www.barrons.com/articles/stocks-today-intel-record-earnings-calendar-79b5fb0e?siteid=yhoof2&yptr=yahoo',
#   'publisher': 'Barrons.com',
#   'published_at': '2026-04-24T23:55:00Z'}]

# %%
client.get_info('AAPL')
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple Vision Pro, Apple TV, Apple Watch, Beats products, and HomePod, as well as Apple branded and third-party accessories. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV, which offers exclusive original content and live sports; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers and resellers. The company was formerly known as Apple Computer, Inc. and changed its name to Apple Inc. in January 2007. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.',
#  'fullTimeEmployees': 150000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Timothy D. Cook',
#    'age': 64,
#    'title': 'CEO & Director',
#    'yearBorn': 1961,
#    'fiscalYear': 2025,
#    'totalPay': 16759518,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Kevan  Parekh',
#    'age': 53,
#    'title': 'Senior VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2025,
#    'totalPay': 4034174,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Sabih  Khan',
#    'age': 58,
#    'title': 'Senior VP & Chief Operating Officer',
#    'yearBorn': 1967,
#    'fiscalYear': 2025,
#    'totalPay': 5021905,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': "Ms. Deirdre  O'Brien",
#    'age': 58,
#    'title': 'Senior Vice President of Retail & People',
#    'yearBorn': 1967,
#    'fiscalYear': 2025,
#    'totalPay': 5037867,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Katherine L. Adams',
#    'age': 61,
#    'title': 'Senior VP of Government Affairs & Secretary',
#    'yearBorn': 1964,
#    'fiscalYear': 2025,
#    'totalPay': 5022482,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Ben  Borders',
#    'age': 44,
#    'title': 'Principal Accounting Officer',
#    'yearBorn': 1981,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Suhasini  Chandramouli',
#    'title': 'Director of Investor Relations',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Jennifer G. Newstead J.D.',
#    'age': 54,
#    'title': 'Senior VP & General Counsel',
#    'yearBorn': 1971,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Kristin Huguet Quayle',
#    'title': 'Vice President of Worldwide Communications',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Greg  Joswiak',
#    'title': 'Senior Vice President of Worldwide Marketing',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 2,
#  'boardRisk': 1,
#  'compensationRisk': 7,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 1,
#  'governanceEpochDate': 1775001600,
#  'compensationAsOfEpochDate': 1767139200,
#  'irWebsite': 'http://investor.apple.com/',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 273.43,
#  'open': 272.76,
#  'dayLow': 269.67,
#  'dayHigh': 273.06,
#  'regularMarketPreviousClose': 273.43,
#  'regularMarketOpen': 272.76,
#  'regularMarketDayLow': 269.67,
#  'regularMarketDayHigh': 273.06,
#  'dividendRate': 1.04,
#  'dividendYield': 0.38,
#  'exDividendDate': 1770595200,
#  'payoutRatio': 0.1304,
#  'fiveYearAvgDividendYield': 0.51,
#  'beta': 1.109,
#  'trailingPE': 34.35488,
#  'forwardPE': 28.92041,
#  'volume': 38033227,
#  'regularMarketVolume': 38033227,
#  'averageVolume': 45866346,
#  'averageVolume10days': 44085150,
#  'averageDailyVolume10Day': 44085150,
#  'bid': 266.0,
#  'ask': 286.63,
#  'bidSize': 1,
#  'askSize': 1,
#  'marketCap': 3979469914112,
#  'nonDilutedMarketCap': 3979469808400,
#  'fiftyTwoWeekLow': 193.25,
#  'fiftyTwoWeekHigh': 288.62,
#  'allTimeHigh': 288.62,
#  'allTimeLow': 0.049107,
#  'priceToSalesTrailing12Months': 9.135249,
#  'fiftyDayAverage': 260.1454,
#  'twoHundredDayAverage': 253.6407,
#  'trailingAnnualDividendRate': 1.03,
#  'trailingAnnualDividendYield': 0.0037669605,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 4003071787008,
#  'profitMargins': 0.27037,
#  'floatShares': 14656035251,
#  'sharesOutstanding': 14681140000,
#  'sharesShort': 134422787,
#  'sharesShortPriorMonth': 124192030,
#  'sharesShortPreviousMonthDate': 1773360000,
#  'dateShortInterest': 1776211200,
#  'sharesPercentSharesOut': 0.0092,
#  'heldPercentInsiders': 0.0164,
#  'heldPercentInstitutions': 0.65225,
#  'shortRatio': 3.24,
#  'shortPercentOfFloat': 0.0092,
#  'impliedSharesOutstanding': 14681140000,
#  'bookValue': 5.998,
#  'priceToBook': 45.19173,
#  'lastFiscalYearEnd': 1758931200,
#  'nextFiscalYearEnd': 1790467200,
#  'mostRecentQuarter': 1766793600,
#  'earningsQuarterlyGrowth': 0.159,
#  'netIncomeToCommon': 117776998400,
#  'trailingEps': 7.89,
#  'forwardEps': 9.37262,
#  'pegRatio': 2.44,
#  'lastSplitFactor': '4:1',
#  'lastSplitDate': 1598832000,
#  'enterpriseToRevenue': 9.189,
#  'enterpriseToEbitda': 26.181,
#  '52WeekChange': 0.28990197,
#  'SandP52WeekChange': 0.29596746,
#  'lastDividendValue': 0.26,
#  'lastDividendDate': 1770595200,
#  'quoteType': 'EQUITY',
#  'currentPrice': 271.06,
#  'targetHighPrice': 350.0,
#  'targetLowPrice': 215.0,
#  'targetMeanPrice': 297.7055,
#  'targetMedianPrice': 300.0,
#  'recommendationMean': 1.89362,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 40,
#  'totalCash': 66907000832,
#  'totalCashPerShare': 4.557,
#  'ebitda': 152901992448,
#  'totalDebt': 90509000704,
#  'quickRatio': 0.845,
#  'currentRatio': 0.974,
#  'totalRevenue': 435617005568,
#  'debtToEquity': 102.63,
#  'revenuePerShare': 29.305,
#  'returnOnAssets': 0.24377,
#  'returnOnEquity': 1.5202099,
#  'grossProfits': 206157004800,
#  'freeCashflow': 106312753152,
#  'operatingCashflow': 135471996928,
#  'earningsGrowth': 0.183,
#  'revenueGrowth': 0.157,
#  'grossMargins': 0.47325,
#  'ebitdaMargins': 0.35099998,
#  'operatingMargins': 0.35374,
#  'financialCurrency': 'USD',
#  'symbol': 'AAPL',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'averageAnalystRating': '1.9 - Buy',
#  'cryptoTradeable': False,
#  'marketState': 'CLOSED',
#  'corporateActions': [],
#  'postMarketTime': 1777075193,
#  'regularMarketTime': 1777060801,
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 345479400000,
#  'postMarketChangePercent': -0.04426884,
#  'postMarketPrice': 270.94,
#  'postMarketChange': -0.11999512,
#  'regularMarketChange': -2.37,
#  'regularMarketDayRange': '269.67 - 273.06',
#  'fullExchangeName': 'NasdaqGS',
#  'averageDailyVolume3Month': 45866346,
#  'fiftyTwoWeekLowChange': 77.81,
#  'fiftyTwoWeekLowChangePercent': 0.40263906,
#  'fiftyTwoWeekRange': '193.25 - 288.62',
#  'fiftyTwoWeekHighChange': -17.559998,
#  'fiftyTwoWeekHighChangePercent': -0.060841236,
#  'fiftyTwoWeekChangePercent': 28.990196,
#  'dividendDate': 1770854400,
#  'earningsTimestamp': 1777579200,
#  'earningsTimestampStart': 1777579200,
#  'earningsTimestampEnd': 1777579200,
#  'earningsCallTimestampStart': 1777582800,
#  'earningsCallTimestampEnd': 1777582800,
#  'isEarningsDateEstimate': False,
#  'epsTrailingTwelveMonths': 7.89,
#  'epsForward': 9.37262,
#  'epsCurrentYear': 8.53797,
#  'priceEpsCurrentYear': 31.747595,
#  'fiftyDayAverageChange': 10.914612,
#  'fiftyDayAverageChangePercent': 0.041955814,
#  'twoHundredDayAverageChange': 17.419296,
#  'twoHundredDayAverageChangePercent': 0.06867705,
#  'exchange': 'NMS',
#  'messageBoardId': 'finmb_24937',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'regularMarketChangePercent': -0.866765,
#  'regularMarketPrice': 271.06,
#  'displayName': 'Apple',
#  'trailingPegRatio': 2.4401}

# %%
client.get_history ("AAPL", period='1mo', interval = '1d',adjusted= True)
# Out:
# [{'date': Timestamp('2026-03-25 00:00:00-0400', tz='America/New_York'),
#   'open': 254.10000610351562,
#   'high': 255.0,
#   'low': 251.60000610351562,
#   'adj_close': 252.6199951171875,
#   'volume': 28476700,
#   'adjusted': True},
#  {'date': Timestamp('2026-03-26 00:00:00-0400', tz='America/New_York'),
#   'open': 252.1199951171875,
#   'high': 257.0,
#   'low': 250.77000427246094,
#   'adj_close': 252.88999938964844,
#   'volume': 41796700,
#   'adjusted': True},
#  {'date': Timestamp('2026-03-27 00:00:00-0400', tz='America/New_York'),
#   'open': 253.89999389648438,
#   'high': 255.49000549316406,
#   'low': 248.07000732421875,
#   'adj_close': 248.8000030517578,
#   'volume': 47900000,
#   'adjusted': True},
#  {'date': Timestamp('2026-03-30 00:00:00-0400', tz='America/New_York'),
#   'open': 250.07000732421875,
#   'high': 250.8699951171875,
#   'low': 245.50999450683594,
#   'adj_close': 246.6300048828125,
#   'volume': 39446200,
#   'adjusted': True},
#  {'date': Timestamp('2026-03-31 00:00:00-0400', tz='America/New_York'),
#   'open': 247.91000366210938,
#   'high': 255.47999572753906,
#   'low': 247.10000610351562,
#   'adj_close': 253.7899932861328,
#   'volume': 49598100,
#   'adjusted': True},
#  {'date': Timestamp('2026-04-01 00:00:00-0400', tz='America/New_York'),
#   'open': 254.0800018310547,
#   'high': 256.17999267578125,
#   'low': 253.3300018310547,
#   'adj_close': 255.6300048828125,
#   'volume': 40059400,
#   'adjusted': True},
#  {'date': Timestamp('2026-04-02 00:00:00-0400', tz='America/New_York'),
#   'open': 254.1999969482422,
#   'high': 256.1300048828125,
#   'low': 250.64999389648438,
#   'adj_close': 255.9199981689453,
#   'volume': 31289400,
#   'adjusted': True},
#  {'date': Timestamp('2026-04-06 00:00:00-0400', tz='America/New_York'),
#   'open': 256.510009765625,
#   'high': 262.1600036621094,
#   'low': 256.4599914550781,
#   'adj_close': 258.8599853515625,
#   'volume': 29329900,
#   'adjusted': True},
#  {'date': Timestamp('2026-04-07 00:00:00-0400', tz='America/New_York'),
#   'open': 256.1600036621094,
#   'high': 256.20001220703125,
#   'low': 245.6999969482422,
#   'adj_close': 253.5,
#   'volume': 62148000,
#   'adjusted': True},
#  {'date': Timestamp('2026-04-08 00:00:00-0400', tz='America/New_York'),
#   'open': 258.45001220703125,
#   'high': 259.75,
#   'low': 256.5299987792969,
#   'adj_close': 258.8999938964844,
#   'volume': 41032800,
#   'adjusted': True},
#  {'date': Timestamp('2026-04-09 00:00:00-0400', tz='America/New_York'),
#   'open': 259.0,
#   'high': 261.1199951171875,
#   'low': 256.07000732421875,
#   'adj_close': 260.489990234375,
#   'volume': 28121600,
#   'adjusted': True},
#  {'date': Timestamp('2026-04-10 00:00:00-0400', tz='America/New_York'),
#   'open': 259.9800109863281,
#   'high': 262.19000244140625,
#   'low': 259.0199890136719,
#   'adj_close': 260.4800109863281,
#   'volume': 31291500,
#   'adjusted': True},
#  {'date': Timestamp('2026-04-13 00:00:00-0400', tz='America/New_York'),
#   'open': 259.7300109863281,
#   'high': 260.17999267578125,
#   'low': 256.6600036621094,
#   'adj_close': 259.20001220703125,
#   'volume': 36234700,
#   'adjusted': True},
#  {'date': Timestamp('2026-04-14 00:00:00-0400', tz='America/New_York'),
#   'open': 259.25,
#   'high': 261.92999267578125,
#   'low': 257.19000244140625,
#   'adj_close': 258.8299865722656,
#   'volume': 48370700,
#   'adjusted': True},
#  {'date': Timestamp('2026-04-15 00:00:00-0400', tz='America/New_York'),
#   'open': 258.1600036621094,
#   'high': 266.55999755859375,
#   'low': 257.80999755859375,
#   'adj_close': 266.42999267578125,
#   'volume': 49913500,
#   'adjusted': True},
#  {'date': Timestamp('2026-04-16 00:00:00-0400', tz='America/New_York'),
#   'open': 266.79998779296875,
#   'high': 267.1600036621094,
#   'low': 261.2699890136719,
#   'adj_close': 263.3999938964844,
#   'volume': 43323100,
#   'adjusted': True},
#  {'date': Timestamp('2026-04-17 00:00:00-0400', tz='America/New_York'),
#   'open': 266.9599914550781,
#   'high': 272.29998779296875,
#   'low': 266.7200012207031,
#   'adj_close': 270.2300109863281,
#   'volume': 61436200,
#   'adjusted': True},
#  {'date': Timestamp('2026-04-20 00:00:00-0400', tz='America/New_York'),
#   'open': 270.3299865722656,
#   'high': 274.2799987792969,
#   'low': 270.2900085449219,
#   'adj_close': 273.04998779296875,
#   'volume': 36590200,
#   'adjusted': True},
#  {'date': Timestamp('2026-04-21 00:00:00-0400', tz='America/New_York'),
#   'open': 271.5,
#   'high': 272.79998779296875,
#   'low': 265.3999938964844,
#   'adj_close': 266.1700134277344,
#   'volume': 50209800,
#   'adjusted': True},
#  {'date': Timestamp('2026-04-22 00:00:00-0400', tz='America/New_York'),
#   'open': 267.82000732421875,
#   'high': 273.739990234375,
#   'low': 266.8699951171875,
#   'adj_close': 273.1700134277344,
#   'volume': 43249200,
#   'adjusted': True},
#  {'date': Timestamp('2026-04-23 00:00:00-0400', tz='America/New_York'),
#   'open': 275.04998779296875,
#   'high': 275.7699890136719,
#   'low': 271.6499938964844,
#   'adj_close': 273.42999267578125,
#   'volume': 33399600,
#   'adjusted': True},
#  {'date': Timestamp('2026-04-24 00:00:00-0400', tz='America/New_York'),
#   'open': 272.760009765625,
#   'high': 273.05999755859375,
#   'low': 269.6499938964844,
#   'adj_close': 271.05999755859375,
#   'volume': 38124500,
#   'adjusted': True}]

# %%
client.get_financials('INTC')
# Out:
# {'income_statement': {Timestamp('2025-12-31 00:00:00'): {'Tax Effect Of Unusual Items': 388710000.0,
#    'Tax Rate For Calcs': 0.21,
#    'Normalized EBITDA': 12503000000.0,
#    'Total Unusual Items': 1851000000.0,
#    'Total Unusual Items Excluding Goodwill': 1851000000.0,
#    'Net Income From Continuing Operation Net Minority Interest': -267000000.0,
#    'Reconciled Depreciation': 11706000000.0,
#    'Reconciled Cost Of Revenue': 34478000000.0,
#    'EBITDA': 14354000000.0,
#    'EBIT': 2648000000.0,
#    'Net Interest Income': -271000000.0,
#    'Interest Expense': 1091000000.0,
#    'Interest Income': 1007000000.0,
#    'Normalized Income': -1729290000.0,
#    'Net Income From Continuing And Discontinued Operation': -267000000.0,
#    'Total Expenses': 52876000000.0,
#    'Total Operating Income As Reported': -2214000000.0,
#    'Diluted Average Shares': 4530000000.0,
#    'Basic Average Shares': 4530000000.0,
#    'Diluted EPS': -0.06,
#    'Basic EPS': -0.06,
#    'Diluted NI Availto Com Stockholders': -267000000.0,
#    'Net Income Common Stockholders': -267000000.0,
#    'Net Income': -267000000.0,
#    'Minority Interests': -293000000.0,
#    'Net Income Including Noncontrolling Interests': 26000000.0,
#    'Net Income Continuous Operations': 26000000.0,
#    'Tax Provision': 1531000000.0,
#    'Pretax Income': 1557000000.0,
#    'Other Income Expense': 1851000000.0,
#    'Special Income Charges': 2833000000.0,
#    'Gain On Sale Of Business': 5324000000.0,
#    'Other Special Charges': -121000000.0,
#    'Write Off': 822000000.0,
#    'Restructuring And Mergern Acquisition': 1790000000.0,
#    'Gain On Sale Of Security': -982000000.0,
#    'Net Non Operating Interest Income Expense': -271000000.0,
#    'Total Other Finance Cost': 187000000.0,
#    'Interest Expense Non Operating': 1091000000.0,
#    'Interest Income Non Operating': 1007000000.0,
#    'Operating Income': -23000000.0,
#    'Operating Expense': 18398000000.0,
#    'Research And Development': 13774000000.0,
#    'Selling General And Administration': 4624000000.0,
#    'Gross Profit': 18375000000.0,
#    'Cost Of Revenue': 34478000000.0,
#    'Total Revenue': 52853000000.0,
#    'Operating Revenue': 52853000000.0},
#   Timestamp('2024-12-31 00:00:00'): {'Tax Effect Of Unusual Items': -1571430000.0,
#    'Tax Rate For Calcs': 0.21,
#    'Normalized EBITDA': 8686000000.0,
#    'Total Unusual Items': -7483000000.0,
#    'Total Unusual Items Excluding Goodwill': -7483000000.0,
#    'Net Income From Continuing Operation Net Minority Interest': -18756000000.0,
#    'Reconciled Depreciation': 11379000000.0,
#    'Reconciled Cost Of Revenue': 35756000000.0,
#    'EBITDA': 1203000000.0,
#    'EBIT': -10176000000.0,
#    'Net Interest Income': 981000000.0,
#    'Interest Expense': 1034000000.0,
#    'Interest Income': 1805000000.0,
#    'Normalized Income': -12844430000.0,
#    'Net Income From Continuing And Discontinued Operation': -18756000000.0,
#    'Total Expenses': 57809000000.0,
#    'Total Operating Income As Reported': -11678000000.0,
#    'Diluted Average Shares': 4280000000.0,
#    'Basic Average Shares': 4280000000.0,
#    'Diluted EPS': -4.38,
#    'Basic EPS': -4.38,
#    'Diluted NI Availto Com Stockholders': -18756000000.0,
#    'Net Income Common Stockholders': -18756000000.0,
#    'Net Income': -18756000000.0,
#    'Minority Interests': 477000000.0,
#    'Net Income Including Noncontrolling Interests': -19233000000.0,
#    'Net Income Continuous Operations': -19233000000.0,
#    'Tax Provision': 8023000000.0,
#    'Pretax Income': -11210000000.0,
#    'Other Income Expense': -7483000000.0,
#    'Special Income Charges': -7317000000.0,
#    'Gain On Sale Of Business': 0.0,
#    'Other Special Charges': 858000000.0,
#    'Write Off': 3978000000.0,
#    'Restructuring And Mergern Acquisition': 2481000000.0,
#    'Gain On Sale Of Security': -166000000.0,
#    'Net Non Operating Interest Income Expense': 981000000.0,
#    'Total Other Finance Cost': -210000000.0,
#    'Interest Expense Non Operating': 1034000000.0,
#    'Interest Income Non Operating': 1805000000.0,
#    'Operating Income': -4708000000.0,
#    'Operating Expense': 22053000000.0,
#    'Research And Development': 16546000000.0,
#    'Selling General And Administration': 5507000000.0,
#    'Gross Profit': 17345000000.0,
#    'Cost Of Revenue': 35756000000.0,
#    'Total Revenue': 53101000000.0,
#    'Operating Revenue': 53101000000.0},
#   Timestamp('2023-12-31 00:00:00'): {'Tax Effect Of Unusual Items': 21420000.0,
#    'Tax Rate For Calcs': 0.21,
#    'Normalized EBITDA': 11140000000.0,
#    'Total Unusual Items': 102000000.0,
#    'Total Unusual Items Excluding Goodwill': 102000000.0,
#    'Net Income From Continuing Operation Net Minority Interest': 1689000000.0,
#    'Reconciled Depreciation': 9602000000.0,
#    'Reconciled Cost Of Revenue': 32517000000.0,
#    'EBITDA': 11242000000.0,
#    'EBIT': 1640000000.0,
#    'Net Interest Income': 629000000.0,
#    'Interest Expense': 878000000.0,
#    'Interest Income': 1335000000.0,
#    'Normalized Income': 1608420000.0,
#    'Net Income From Continuing And Discontinued Operation': 1689000000.0,
#    'Total Expenses': 54197000000.0,
#    'Total Operating Income As Reported': 93000000.0,
#    'Diluted Average Shares': 4212000000.0,
#    'Basic Average Shares': 4190000000.0,
#    'Diluted EPS': 0.4,
#    'Basic EPS': 0.4,
#    'Diluted NI Availto Com Stockholders': 1689000000.0,
#    'Net Income Common Stockholders': 1689000000.0,
#    'Net Income': 1689000000.0,
#    'Minority Interests': 14000000.0,
#    'Net Income Including Noncontrolling Interests': 1675000000.0,
#    'Net Income Continuous Operations': 1675000000.0,
#    'Tax Provision': -913000000.0,
#    'Pretax Income': 762000000.0,
#    'Other Income Expense': 102000000.0,
#    'Special Income Charges': -152000000.0,
#    'Gain On Sale Of Business': 0.0,
#    'Other Special Charges': -329000000.0,
#    'Write Off': 259000000.0,
#    'Restructuring And Mergern Acquisition': 222000000.0,
#    'Gain On Sale Of Security': 254000000.0,
#    'Net Non Operating Interest Income Expense': 629000000.0,
#    'Total Other Finance Cost': -172000000.0,
#    'Interest Expense Non Operating': 878000000.0,
#    'Interest Income Non Operating': 1335000000.0,
#    'Operating Income': 31000000.0,
#    'Operating Expense': 21680000000.0,
#    'Research And Development': 16046000000.0,
#    'Selling General And Administration': 5634000000.0,
#    'Gross Profit': 21711000000.0,
#    'Cost Of Revenue': 32517000000.0,
#    'Total Revenue': 54228000000.0,
#    'Operating Revenue': 54228000000.0},
#   Timestamp('2022-12-31 00:00:00'): {'Tax Effect Of Unusual Items': 1105860000.0,
#    'Tax Rate For Calcs': 0.21,
#    'Normalized EBITDA': 16033000000.0,
#    'Total Unusual Items': 5266000000.0,
#    'Total Unusual Items Excluding Goodwill': 5266000000.0,
#    'Net Income From Continuing Operation Net Minority Interest': 8014000000.0,
#    'Reconciled Depreciation': 13035000000.0,
#    'Reconciled Cost Of Revenue': 36188000000.0,
#    'EBITDA': 21299000000.0,
#    'EBIT': 8264000000.0,
#    'Net Interest Income': 166000000.0,
#    'Interest Expense': 496000000.0,
#    'Interest Income': 589000000.0,
#    'Normalized Income': 3853860000.0,
#    'Net Income From Continuing And Discontinued Operation': 8014000000.0,
#    'Total Expenses': 60718000000.0,
#    'Total Operating Income As Reported': 2334000000.0,
#    'Diluted Average Shares': 4123000000.0,
#    'Basic Average Shares': 4108000000.0,
#    'Diluted EPS': 1.94,
#    'Basic EPS': 1.95,
#    'Diluted NI Availto Com Stockholders': 8014000000.0,
#    'Net Income Common Stockholders': 8014000000.0,
#    'Net Income': 8014000000.0,
#    'Minority Interests': -3000000.0,
#    'Net Income Including Noncontrolling Interests': 8017000000.0,
#    'Net Income Continuous Operations': 8017000000.0,
#    'Tax Provision': -249000000.0,
#    'Pretax Income': 7768000000.0,
#    'Other Income Expense': 5266000000.0,
#    'Special Income Charges': 808000000.0,
#    'Gain On Sale Of Business': 1000000000.0,
#    'Other Special Charges': -1187000000.0,
#    'Write Off': 341000000.0,
#    'Restructuring And Mergern Acquisition': 1038000000.0,
#    'Gain On Sale Of Security': 4458000000.0,
#    'Net Non Operating Interest Income Expense': 166000000.0,
#    'Total Other Finance Cost': -73000000.0,
#    'Interest Expense Non Operating': 496000000.0,
#    'Interest Income Non Operating': 589000000.0,
#    'Operating Income': 2336000000.0,
#    'Operating Expense': 24530000000.0,
#    'Research And Development': 17528000000.0,
#    'Selling General And Administration': 7002000000.0,
#    'Gross Profit': 26866000000.0,
#    'Cost Of Revenue': 36188000000.0,
#    'Total Revenue': 63054000000.0,
#    'Operating Revenue': 63054000000.0}},
#  'balance_sheet': {Timestamp('2025-12-31 00:00:00'): {'Treasury Shares Number': nan,
#    'Ordinary Shares Number': 4994000000.0,
#    'Share Issued': 4994000000.0,
#    'Net Debt': 32320000000.0,
#    'Total Debt': 46585000000.0,
#    'Tangible Book Value': 87597000000.0,
#    'Invested Capital': 160866000000.0,
#    'Working Capital': 32113000000.0,
#    'Net Tangible Assets': 87597000000.0,
#    'Common Stock Equity': 114281000000.0,
#    'Total Capitalization': 158367000000.0,
#    'Total Equity Gross Minority Interest': 126360000000.0,
#    'Minority Interest': 12079000000.0,
#    'Stockholders Equity': 114281000000.0,
#    'Gains Losses Not Affecting Retained Earnings': 113000000.0,
#    'Other Equity Adjustments': 113000000.0,
#    'Retained Earnings': 48983000000.0,
#    'Capital Stock': 65185000000.0,
#    'Common Stock': 65185000000.0,
#    'Preferred Stock': 0.0,
#    'Total Liabilities Net Minority Interest': 85069000000.0,
#    'Total Non Current Liabilities Net Minority Interest': 53494000000.0,
#    'Other Non Current Liabilities': 9408000000.0,
#    'Tradeand Other Payables Non Current': nan,
#    'Non Current Deferred Liabilities': nan,
#    'Non Current Deferred Revenue': nan,
#    'Non Current Deferred Taxes Liabilities': nan,
#    'Long Term Debt And Capital Lease Obligation': 44086000000.0,
#    'Long Term Debt': 44086000000.0,
#    'Current Liabilities': 31575000000.0,
#    'Other Current Liabilities': nan,
#    'Current Deferred Liabilities': nan,
#    'Current Debt And Capital Lease Obligation': 2499000000.0,
#    'Current Debt': 2499000000.0,
#    'Other Current Borrowings': 2499000000.0,
#    'Commercial Paper': nan,
#    'Pensionand Other Post Retirement Benefit Plans Current': 3990000000.0,
#    'Payables And Accrued Expenses': 25086000000.0,
#    'Current Accrued Expenses': 14600000000.0,
#    'Payables': 10486000000.0,
#    'Total Tax Payable': 604000000.0,
#    'Income Tax Payable': 604000000.0,
#    'Accounts Payable': 9882000000.0,
#    'Total Assets': 211429000000.0,
#    'Total Non Current Assets': 147741000000.0,
#    'Other Non Current Assets': 7131000000.0,
#    'Investments And Advances': 8512000000.0,
#    'Other Investments': nan,
#    'Investmentin Financial Assets': 8512000000.0,
#    'Available For Sale Securities': 8512000000.0,
#    'Long Term Equity Investment': nan,
#    'Investments In Other Ventures Under Equity Method': nan,
#    'Goodwill And Other Intangible Assets': 26684000000.0,
#    'Other Intangible Assets': 2772000000.0,
#    'Goodwill': 23912000000.0,
#    'Net PPE': 105414000000.0,
#    'Accumulated Depreciation': -106464000000.0,
#    'Gross PPE': 211878000000.0,
#    'Construction In Progress': 34543000000.0,
#    'Machinery Furniture Equipment': 111940000000.0,
#    'Properties': 65395000000.0,
#    'Current Assets': 63688000000.0,
#    'Other Current Assets': 10815000000.0,
#    'Assets Held For Sale Current': nan,
#    'Inventory': 11618000000.0,
#    'Finished Goods': 2785000000.0,
#    'Work In Process': 7840000000.0,
#    'Raw Materials': 993000000.0,
#    'Receivables': 3839000000.0,
#    'Accounts Receivable': 3839000000.0,
#    'Cash Cash Equivalents And Short Term Investments': 37416000000.0,
#    'Other Short Term Investments': 23151000000.0,
#    'Cash And Cash Equivalents': 14265000000.0},
#   Timestamp('2024-12-31 00:00:00'): {'Treasury Shares Number': nan,
#    'Ordinary Shares Number': 4330000000.0,
#    'Share Issued': 4330000000.0,
#    'Net Debt': 41762000000.0,
#    'Total Debt': 50011000000.0,
#    'Tangible Book Value': 70886000000.0,
#    'Invested Capital': 149281000000.0,
#    'Working Capital': 11658000000.0,
#    'Net Tangible Assets': 70886000000.0,
#    'Common Stock Equity': 99270000000.0,
#    'Total Capitalization': 145552000000.0,
#    'Total Equity Gross Minority Interest': 105032000000.0,
#    'Minority Interest': 5762000000.0,
#    'Stockholders Equity': 99270000000.0,
#    'Gains Losses Not Affecting Retained Earnings': -711000000.0,
#    'Other Equity Adjustments': -711000000.0,
#    'Retained Earnings': 49032000000.0,
#    'Capital Stock': 50949000000.0,
#    'Common Stock': 50949000000.0,
#    'Preferred Stock': 0.0,
#    'Total Liabilities Net Minority Interest': 91453000000.0,
#    'Total Non Current Liabilities Net Minority Interest': 55787000000.0,
#    'Other Non Current Liabilities': 9505000000.0,
#    'Tradeand Other Payables Non Current': nan,
#    'Non Current Deferred Liabilities': nan,
#    'Non Current Deferred Revenue': nan,
#    'Non Current Deferred Taxes Liabilities': nan,
#    'Long Term Debt And Capital Lease Obligation': 46282000000.0,
#    'Long Term Debt': 46282000000.0,
#    'Current Liabilities': 35666000000.0,
#    'Other Current Liabilities': nan,
#    'Current Deferred Liabilities': nan,
#    'Current Debt And Capital Lease Obligation': 3729000000.0,
#    'Current Debt': 3729000000.0,
#    'Other Current Borrowings': 3729000000.0,
#    'Commercial Paper': nan,
#    'Pensionand Other Post Retirement Benefit Plans Current': 3343000000.0,
#    'Payables And Accrued Expenses': 28594000000.0,
#    'Current Accrued Expenses': 14282000000.0,
#    'Payables': 14312000000.0,
#    'Total Tax Payable': 1756000000.0,
#    'Income Tax Payable': 1756000000.0,
#    'Accounts Payable': 12556000000.0,
#    'Total Assets': 196485000000.0,
#    'Total Non Current Assets': 149161000000.0,
#    'Other Non Current Assets': 7475000000.0,
#    'Investments And Advances': 5383000000.0,
#    'Other Investments': nan,
#    'Investmentin Financial Assets': 5383000000.0,
#    'Available For Sale Securities': 5383000000.0,
#    'Long Term Equity Investment': nan,
#    'Investments In Other Ventures Under Equity Method': nan,
#    'Goodwill And Other Intangible Assets': 28384000000.0,
#    'Other Intangible Assets': 3691000000.0,
#    'Goodwill': 24693000000.0,
#    'Net PPE': 107919000000.0,
#    'Accumulated Depreciation': -102193000000.0,
#    'Gross PPE': 210112000000.0,
#    'Construction In Progress': 50418000000.0,
#    'Machinery Furniture Equipment': 103150000000.0,
#    'Properties': 56544000000.0,
#    'Current Assets': 47324000000.0,
#    'Other Current Assets': 9586000000.0,
#    'Assets Held For Sale Current': nan,
#    'Inventory': 12198000000.0,
#    'Finished Goods': 3422000000.0,
#    'Work In Process': 7432000000.0,
#    'Raw Materials': 1344000000.0,
#    'Receivables': 3478000000.0,
#    'Accounts Receivable': 3478000000.0,
#    'Cash Cash Equivalents And Short Term Investments': 22062000000.0,
#    'Other Short Term Investments': 13813000000.0,
#    'Cash And Cash Equivalents': 8249000000.0},
#   Timestamp('2023-12-31 00:00:00'): {'Treasury Shares Number': 0.0,
#    'Ordinary Shares Number': 4228000000.0,
#    'Share Issued': 4228000000.0,
#    'Net Debt': 42187000000.0,
#    'Total Debt': 49266000000.0,
#    'Tangible Book Value': 73410000000.0,
#    'Invested Capital': 154856000000.0,
#    'Working Capital': 15216000000.0,
#    'Net Tangible Assets': 73410000000.0,
#    'Common Stock Equity': 105590000000.0,
#    'Total Capitalization': 152568000000.0,
#    'Total Equity Gross Minority Interest': 109965000000.0,
#    'Minority Interest': 4375000000.0,
#    'Stockholders Equity': 105590000000.0,
#    'Gains Losses Not Affecting Retained Earnings': -215000000.0,
#    'Other Equity Adjustments': -215000000.0,
#    'Retained Earnings': 69156000000.0,
#    'Capital Stock': 36649000000.0,
#    'Common Stock': 36649000000.0,
#    'Preferred Stock': 0.0,
#    'Total Liabilities Net Minority Interest': 81607000000.0,
#    'Total Non Current Liabilities Net Minority Interest': 53554000000.0,
#    'Other Non Current Liabilities': 6576000000.0,
#    'Tradeand Other Payables Non Current': nan,
#    'Non Current Deferred Liabilities': nan,
#    'Non Current Deferred Revenue': nan,
#    'Non Current Deferred Taxes Liabilities': nan,
#    'Long Term Debt And Capital Lease Obligation': 46978000000.0,
#    'Long Term Debt': 46978000000.0,
#    'Current Liabilities': 28053000000.0,
#    'Other Current Liabilities': -12000000.0,
#    'Current Deferred Liabilities': 2900000000.0,
#    'Current Debt And Capital Lease Obligation': 2288000000.0,
#    'Current Debt': 2288000000.0,
#    'Other Current Borrowings': 2288000000.0,
#    'Commercial Paper': nan,
#    'Pensionand Other Post Retirement Benefit Plans Current': 3655000000.0,
#    'Payables And Accrued Expenses': 22110000000.0,
#    'Current Accrued Expenses': 12425000000.0,
#    'Payables': 9685000000.0,
#    'Total Tax Payable': 1107000000.0,
#    'Income Tax Payable': 1107000000.0,
#    'Accounts Payable': 8578000000.0,
#    'Total Assets': 191572000000.0,
#    'Total Non Current Assets': 148303000000.0,
#    'Other Non Current Assets': 13647000000.0,
#    'Investments And Advances': 5829000000.0,
#    'Other Investments': nan,
#    'Investmentin Financial Assets': 5829000000.0,
#    'Available For Sale Securities': 5829000000.0,
#    'Long Term Equity Investment': 5000000.0,
#    'Investments In Other Ventures Under Equity Method': nan,
#    'Goodwill And Other Intangible Assets': 32180000000.0,
#    'Other Intangible Assets': 4589000000.0,
#    'Goodwill': 27591000000.0,
#    'Net PPE': 96647000000.0,
#    'Accumulated Depreciation': -98010000000.0,
#    'Gross PPE': 194657000000.0,
#    'Construction In Progress': 43442000000.0,
#    'Machinery Furniture Equipment': 100033000000.0,
#    'Properties': 51182000000.0,
#    'Current Assets': 43269000000.0,
#    'Other Current Assets': 3706000000.0,
#    'Assets Held For Sale Current': nan,
#    'Inventory': 11127000000.0,
#    'Finished Goods': 3758000000.0,
#    'Work In Process': 6203000000.0,
#    'Raw Materials': 1166000000.0,
#    'Receivables': 3402000000.0,
#    'Accounts Receivable': 3402000000.0,
#    'Cash Cash Equivalents And Short Term Investments': 25034000000.0,
#    'Other Short Term Investments': 17955000000.0,
#    'Cash And Cash Equivalents': 7079000000.0},
#   Timestamp('2022-12-31 00:00:00'): {'Treasury Shares Number': nan,
#    'Ordinary Shares Number': 4137000000.0,
#    'Share Issued': 4137000000.0,
#    'Net Debt': 30863000000.0,
#    'Total Debt': 42007000000.0,
#    'Tangible Book Value': 67814000000.0,
#    'Invested Capital': 143430000000.0,
#    'Working Capital': 18252000000.0,
#    'Net Tangible Assets': 67814000000.0,
#    'Common Stock Equity': 101423000000.0,
#    'Total Capitalization': 139107000000.0,
#    'Total Equity Gross Minority Interest': 103286000000.0,
#    'Minority Interest': 1863000000.0,
#    'Stockholders Equity': 101423000000.0,
#    'Gains Losses Not Affecting Retained Earnings': -562000000.0,
#    'Other Equity Adjustments': -562000000.0,
#    'Retained Earnings': 70405000000.0,
#    'Capital Stock': 31580000000.0,
#    'Common Stock': 31580000000.0,
#    'Preferred Stock': 0.0,
#    'Total Liabilities Net Minority Interest': 78817000000.0,
#    'Total Non Current Liabilities Net Minority Interest': 46662000000.0,
#    'Other Non Current Liabilities': 8978000000.0,
#    'Tradeand Other Payables Non Current': 3796000000.0,
#    'Non Current Deferred Liabilities': 202000000.0,
#    'Non Current Deferred Revenue': nan,
#    'Non Current Deferred Taxes Liabilities': 202000000.0,
#    'Long Term Debt And Capital Lease Obligation': 37684000000.0,
#    'Long Term Debt': 37684000000.0,
#    'Current Liabilities': 32155000000.0,
#    'Other Current Liabilities': 44000000.0,
#    'Current Deferred Liabilities': 2400000000.0,
#    'Current Debt And Capital Lease Obligation': 4323000000.0,
#    'Current Debt': 4323000000.0,
#    'Other Current Borrowings': 423000000.0,
#    'Commercial Paper': 3900000000.0,
#    'Pensionand Other Post Retirement Benefit Plans Current': 4084000000.0,
#    'Payables And Accrued Expenses': 21304000000.0,
#    'Current Accrued Expenses': 9458000000.0,
#    'Payables': 11846000000.0,
#    'Total Tax Payable': 2251000000.0,
#    'Income Tax Payable': 2251000000.0,
#    'Accounts Payable': 9595000000.0,
#    'Total Assets': 182103000000.0,
#    'Total Non Current Assets': 131696000000.0,
#    'Other Non Current Assets': 11315000000.0,
#    'Investments And Advances': 5912000000.0,
#    'Other Investments': nan,
#    'Investmentin Financial Assets': 5902000000.0,
#    'Available For Sale Securities': 5902000000.0,
#    'Long Term Equity Investment': 10000000.0,
#    'Investments In Other Ventures Under Equity Method': 10000000.0,
#    'Goodwill And Other Intangible Assets': 33609000000.0,
#    'Other Intangible Assets': 6018000000.0,
#    'Goodwill': 27591000000.0,
#    'Net PPE': 80860000000.0,
#    'Accumulated Depreciation': -93386000000.0,
#    'Gross PPE': 174246000000.0,
#    'Construction In Progress': 36727000000.0,
#    'Machinery Furniture Equipment': 92711000000.0,
#    'Properties': 44808000000.0,
#    'Current Assets': 50407000000.0,
#    'Other Current Assets': 4712000000.0,
#    'Assets Held For Sale Current': 45000000.0,
#    'Inventory': 13224000000.0,
#    'Finished Goods': 4142000000.0,
#    'Work In Process': 7565000000.0,
#    'Raw Materials': 1517000000.0,
#    'Receivables': 4133000000.0,
#    'Accounts Receivable': 4133000000.0,
#    'Cash Cash Equivalents And Short Term Investments': 28338000000.0,
#    'Other Short Term Investments': 17194000000.0,
#    'Cash And Cash Equivalents': 11144000000.0},
#   Timestamp('2021-12-31 00:00:00'): {'Treasury Shares Number': nan,
#    'Ordinary Shares Number': nan,
#    'Share Issued': nan,
#    'Net Debt': nan,
#    'Total Debt': nan,
#    'Tangible Book Value': nan,
#    'Invested Capital': nan,
#    'Working Capital': nan,
#    'Net Tangible Assets': nan,
#    'Common Stock Equity': nan,
#    'Total Capitalization': nan,
#    'Total Equity Gross Minority Interest': nan,
#    'Minority Interest': nan,
#    'Stockholders Equity': nan,
#    'Gains Losses Not Affecting Retained Earnings': nan,
#    'Other Equity Adjustments': nan,
#    'Retained Earnings': nan,
#    'Capital Stock': nan,
#    'Common Stock': nan,
#    'Preferred Stock': nan,
#    'Total Liabilities Net Minority Interest': nan,
#    'Total Non Current Liabilities Net Minority Interest': nan,
#    'Other Non Current Liabilities': nan,
#    'Tradeand Other Payables Non Current': 4305000000.0,
#    'Non Current Deferred Liabilities': 2667000000.0,
#    'Non Current Deferred Revenue': 185000000.0,
#    'Non Current Deferred Taxes Liabilities': 2667000000.0,
#    'Long Term Debt And Capital Lease Obligation': nan,
#    'Long Term Debt': nan,
#    'Current Liabilities': nan,
#    'Other Current Liabilities': 991000000.0,
#    'Current Deferred Liabilities': 2800000000.0,
#    'Current Debt And Capital Lease Obligation': nan,
#    'Current Debt': nan,
#    'Other Current Borrowings': nan,
#    'Commercial Paper': 0.0,
#    'Pensionand Other Post Retirement Benefit Plans Current': nan,
#    'Payables And Accrued Expenses': nan,
#    'Current Accrued Expenses': nan,
#    'Payables': nan,
#    'Total Tax Payable': nan,
#    'Income Tax Payable': nan,
#    'Accounts Payable': nan,
#    'Total Assets': nan,
#    'Total Non Current Assets': nan,
#    'Other Non Current Assets': nan,
#    'Investments And Advances': nan,
#    'Other Investments': 840000000.0,
#    'Investmentin Financial Assets': nan,
#    'Available For Sale Securities': nan,
#    'Long Term Equity Investment': 16000000.0,
#    'Investments In Other Ventures Under Equity Method': 16000000.0,
#    'Goodwill And Other Intangible Assets': nan,
#    'Other Intangible Assets': nan,
#    'Goodwill': nan,
#    'Net PPE': nan,
#    'Accumulated Depreciation': nan,
#    'Gross PPE': nan,
#    'Construction In Progress': nan,
#    'Machinery Furniture Equipment': nan,
#    'Properties': nan,
#    'Current Assets': nan,
#    'Other Current Assets': nan,
#    'Assets Held For Sale Current': 6942000000.0,
#    'Inventory': nan,
#    'Finished Goods': nan,
#    'Work In Process': nan,
#    'Raw Materials': nan,
#    'Receivables': nan,
#    'Accounts Receivable': nan,
#    'Cash Cash Equivalents And Short Term Investments': nan,
#    'Other Short Term Investments': nan,
#    'Cash And Cash Equivalents': nan}},
#  'cash_flow': {Timestamp('2025-12-31 00:00:00'): {'Free Cash Flow': -4949000000.0,
#    'Repurchase Of Capital Stock': nan,
#    'Repayment Of Debt': -7243000000.0,
#    'Issuance Of Debt': 3493000000.0,
#    'Issuance Of Capital Stock': nan,
#    'Capital Expenditure': -14646000000.0,
#    'Interest Paid Supplemental Data': 1106000000.0,
#    'Income Tax Paid Supplemental Data': 2299000000.0,
#    'End Cash Position': 14712000000.0,
#    'Beginning Cash Position': 8249000000.0,
#    'Changes In Cash': 6463000000.0,
#    'Financing Cash Flow': 11587000000.0,
#    'Cash Flow From Continuing Financing Activities': 11587000000.0,
#    'Net Other Financing Charges': 1860000000.0,
#    'Proceeds From Stock Option Exercised': 13477000000.0,
#    'Cash Dividends Paid': 0.0,
#    'Common Stock Dividend Paid': 0.0,
#    'Net Common Stock Issuance': nan,
#    'Common Stock Payments': nan,
#    'Common Stock Issuance': nan,
#    'Net Issuance Payments Of Debt': -3750000000.0,
#    'Net Short Term Debt Issuance': 0.0,
#    'Short Term Debt Payments': -3493000000.0,
#    'Short Term Debt Issuance': 3493000000.0,
#    'Net Long Term Debt Issuance': -3750000000.0,
#    'Long Term Debt Payments': -3750000000.0,
#    'Long Term Debt Issuance': 0.0,
#    'Investing Cash Flow': -14821000000.0,
#    'Cash Flow From Continuing Investing Activities': -14821000000.0,
#    'Net Other Investing Changes': 1929000000.0,
#    'Net Investment Purchase And Sale': -8261000000.0,
#    'Sale Of Investment': 16058000000.0,
#    'Purchase Of Investment': -24319000000.0,
#    'Net Business Purchase And Sale': 6157000000.0,
#    'Sale Of Business': 6157000000.0,
#    'Purchase Of Business': nan,
#    'Net PPE Purchase And Sale': -14646000000.0,
#    'Purchase Of PPE': -14646000000.0,
#    'Operating Cash Flow': 9697000000.0,
#    'Cash Flow From Continuing Operating Activities': 9697000000.0,
#    'Change In Working Capital': -1747000000.0,
#    'Change In Other Working Capital': -2245000000.0,
#    'Change In Payables And Accrued Expense': 1085000000.0,
#    'Change In Accrued Expense': 788000000.0,
#    'Change In Payable': 297000000.0,
#    'Change In Account Payable': 297000000.0,
#    'Change In Prepaid Assets': nan,
#    'Change In Inventory': -138000000.0,
#    'Change In Receivables': -449000000.0,
#    'Changes In Account Receivables': -449000000.0,
#    'Other Non Cash Items': 476000000.0,
#    'Stock Based Compensation': 2434000000.0,
#    'Asset Impairment Charge': 515000000.0,
#    'Deferred Tax': 328000000.0,
#    'Deferred Income Tax': 328000000.0,
#    'Depreciation Amortization Depletion': 11706000000.0,
#    'Depreciation And Amortization': 11706000000.0,
#    'Amortization Cash Flow': 949000000.0,
#    'Amortization Of Intangibles': 949000000.0,
#    'Depreciation': 10757000000.0,
#    'Operating Gains Losses': -4041000000.0,
#    'Gain Loss On Investment Securities': 1282000000.0,
#    'Gain Loss On Sale Of Business': -5323000000.0,
#    'Net Income From Continuing Operations': 26000000.0},
#   Timestamp('2024-12-31 00:00:00'): {'Free Cash Flow': -15656000000.0,
#    'Repurchase Of Capital Stock': nan,
#    'Repayment Of Debt': -9637000000.0,
#    'Issuance Of Debt': 10324000000.0,
#    'Issuance Of Capital Stock': 12714000000.0,
#    'Capital Expenditure': -23944000000.0,
#    'Interest Paid Supplemental Data': 987000000.0,
#    'Income Tax Paid Supplemental Data': 2202000000.0,
#    'End Cash Position': 8249000000.0,
#    'Beginning Cash Position': 7079000000.0,
#    'Changes In Cash': 1170000000.0,
#    'Financing Cash Flow': 11138000000.0,
#    'Cash Flow From Continuing Financing Activities': 11138000000.0,
#    'Net Other Financing Charges': 11063000000.0,
#    'Proceeds From Stock Option Exercised': 987000000.0,
#    'Cash Dividends Paid': -1599000000.0,
#    'Common Stock Dividend Paid': -1599000000.0,
#    'Net Common Stock Issuance': 12714000000.0,
#    'Common Stock Payments': nan,
#    'Common Stock Issuance': 12714000000.0,
#    'Net Issuance Payments Of Debt': 687000000.0,
#    'Net Short Term Debt Issuance': 0.0,
#    'Short Term Debt Payments': -7349000000.0,
#    'Short Term Debt Issuance': 7349000000.0,
#    'Net Long Term Debt Issuance': 687000000.0,
#    'Long Term Debt Payments': -2288000000.0,
#    'Long Term Debt Issuance': 2975000000.0,
#    'Investing Cash Flow': -18256000000.0,
#    'Cash Flow From Continuing Investing Activities': -18256000000.0,
#    'Net Other Investing Changes': 1118000000.0,
#    'Net Investment Purchase And Sale': 4570000000.0,
#    'Sale Of Investment': 42510000000.0,
#    'Purchase Of Investment': -37940000000.0,
#    'Net Business Purchase And Sale': 0.0,
#    'Sale Of Business': 0.0,
#    'Purchase Of Business': -82000000.0,
#    'Net PPE Purchase And Sale': -23944000000.0,
#    'Purchase Of PPE': -23944000000.0,
#    'Operating Cash Flow': 8288000000.0,
#    'Cash Flow From Continuing Operating Activities': 8288000000.0,
#    'Change In Working Capital': 1103000000.0,
#    'Change In Other Working Capital': 1867000000.0,
#    'Change In Payables And Accrued Expense': 416000000.0,
#    'Change In Accrued Expense': -218000000.0,
#    'Change In Payable': 634000000.0,
#    'Change In Account Payable': 634000000.0,
#    'Change In Prepaid Assets': nan,
#    'Change In Inventory': -1105000000.0,
#    'Change In Receivables': -75000000.0,
#    'Changes In Account Receivables': -75000000.0,
#    'Other Non Cash Items': 3491000000.0,
#    'Stock Based Compensation': 3410000000.0,
#    'Asset Impairment Charge': 2252000000.0,
#    'Deferred Tax': 6132000000.0,
#    'Deferred Income Tax': 6132000000.0,
#    'Depreciation Amortization Depletion': 11379000000.0,
#    'Depreciation And Amortization': 11379000000.0,
#    'Amortization Cash Flow': 1428000000.0,
#    'Amortization Of Intangibles': 1428000000.0,
#    'Depreciation': 9951000000.0,
#    'Operating Gains Losses': -246000000.0,
#    'Gain Loss On Investment Securities': -246000000.0,
#    'Gain Loss On Sale Of Business': 0.0,
#    'Net Income From Continuing Operations': -19233000000.0},
#   Timestamp('2023-12-31 00:00:00'): {'Free Cash Flow': -14279000000.0,
#    'Repurchase Of Capital Stock': 0.0,
#    'Repayment Of Debt': -4367000000.0,
#    'Issuance Of Debt': 11391000000.0,
#    'Issuance Of Capital Stock': 1511000000.0,
#    'Capital Expenditure': -25750000000.0,
#    'Interest Paid Supplemental Data': 613000000.0,
#    'Income Tax Paid Supplemental Data': 2621000000.0,
#    'End Cash Position': 7079000000.0,
#    'Beginning Cash Position': 11144000000.0,
#    'Changes In Cash': -4065000000.0,
#    'Financing Cash Flow': 8505000000.0,
#    'Cash Flow From Continuing Financing Activities': 8505000000.0,
#    'Net Other Financing Charges': 3527000000.0,
#    'Proceeds From Stock Option Exercised': 1042000000.0,
#    'Cash Dividends Paid': -3088000000.0,
#    'Common Stock Dividend Paid': -3088000000.0,
#    'Net Common Stock Issuance': 0.0,
#    'Common Stock Payments': 0.0,
#    'Common Stock Issuance': 1511000000.0,
#    'Net Issuance Payments Of Debt': 7024000000.0,
#    'Net Short Term Debt Issuance': -3944000000.0,
#    'Short Term Debt Payments': -3944000000.0,
#    'Short Term Debt Issuance': 0.0,
#    'Net Long Term Debt Issuance': 10968000000.0,
#    'Long Term Debt Payments': -423000000.0,
#    'Long Term Debt Issuance': 11391000000.0,
#    'Investing Cash Flow': -24041000000.0,
#    'Cash Flow From Continuing Investing Activities': -24041000000.0,
#    'Net Other Investing Changes': 1574000000.0,
#    'Net Investment Purchase And Sale': 135000000.0,
#    'Sale Of Investment': 44549000000.0,
#    'Purchase Of Investment': -44414000000.0,
#    'Net Business Purchase And Sale': 0.0,
#    'Sale Of Business': 0.0,
#    'Purchase Of Business': -13000000.0,
#    'Net PPE Purchase And Sale': -25750000000.0,
#    'Purchase Of PPE': -25750000000.0,
#    'Operating Cash Flow': 11471000000.0,
#    'Cash Flow From Continuing Operating Activities': 11471000000.0,
#    'Change In Working Capital': -569000000.0,
#    'Change In Other Working Capital': -1982000000.0,
#    'Change In Payables And Accrued Expense': -1415000000.0,
#    'Change In Accrued Expense': -614000000.0,
#    'Change In Payable': -801000000.0,
#    'Change In Account Payable': -801000000.0,
#    'Change In Prepaid Assets': nan,
#    'Change In Inventory': 2097000000.0,
#    'Change In Receivables': 731000000.0,
#    'Changes In Account Receivables': 731000000.0,
#    'Other Non Cash Items': -424000000.0,
#    'Stock Based Compensation': 3229000000.0,
#    'Asset Impairment Charge': 33000000.0,
#    'Deferred Tax': -2033000000.0,
#    'Deferred Income Tax': -2033000000.0,
#    'Depreciation Amortization Depletion': 9602000000.0,
#    'Depreciation And Amortization': 9602000000.0,
#    'Amortization Cash Flow': 1755000000.0,
#    'Amortization Of Intangibles': 1755000000.0,
#    'Depreciation': 7847000000.0,
#    'Operating Gains Losses': -42000000.0,
#    'Gain Loss On Investment Securities': -42000000.0,
#    'Gain Loss On Sale Of Business': 0.0,
#    'Net Income From Continuing Operations': 1675000000.0},
#   Timestamp('2022-12-31 00:00:00'): {'Free Cash Flow': -9411000000.0,
#    'Repurchase Of Capital Stock': 0.0,
#    'Repayment Of Debt': -4984000000.0,
#    'Issuance Of Debt': 10493000000.0,
#    'Issuance Of Capital Stock': 1032000000.0,
#    'Capital Expenditure': -24844000000.0,
#    'Interest Paid Supplemental Data': 459000000.0,
#    'Income Tax Paid Supplemental Data': 4282000000.0,
#    'End Cash Position': 11144000000.0,
#    'Beginning Cash Position': 4827000000.0,
#    'Changes In Cash': 6317000000.0,
#    'Financing Cash Flow': 1115000000.0,
#    'Cash Flow From Continuing Financing Activities': 1115000000.0,
#    'Net Other Financing Charges': 626000000.0,
#    'Proceeds From Stock Option Exercised': 977000000.0,
#    'Cash Dividends Paid': -5997000000.0,
#    'Common Stock Dividend Paid': -5997000000.0,
#    'Net Common Stock Issuance': 1032000000.0,
#    'Common Stock Payments': 0.0,
#    'Common Stock Issuance': 1032000000.0,
#    'Net Issuance Payments Of Debt': 5509000000.0,
#    'Net Short Term Debt Issuance': 3945000000.0,
#    'Short Term Debt Payments': 0.0,
#    'Short Term Debt Issuance': 3945000000.0,
#    'Net Long Term Debt Issuance': 1564000000.0,
#    'Long Term Debt Payments': -4984000000.0,
#    'Long Term Debt Issuance': 6548000000.0,
#    'Investing Cash Flow': -10231000000.0,
#    'Cash Flow From Continuing Investing Activities': -10231000000.0,
#    'Net Other Investing Changes': -1329000000.0,
#    'Net Investment Purchase And Sale': 10044000000.0,
#    'Sale Of Investment': 53691000000.0,
#    'Purchase Of Investment': -43647000000.0,
#    'Net Business Purchase And Sale': 5898000000.0,
#    'Sale Of Business': 6579000000.0,
#    'Purchase Of Business': -681000000.0,
#    'Net PPE Purchase And Sale': -24844000000.0,
#    'Purchase Of PPE': -24844000000.0,
#    'Operating Cash Flow': 15433000000.0,
#    'Cash Flow From Continuing Operating Activities': 15433000000.0,
#    'Change In Working Capital': 339000000.0,
#    'Change In Other Working Capital': -990000000.0,
#    'Change In Payables And Accrued Expense': -1562000000.0,
#    'Change In Accrued Expense': -1533000000.0,
#    'Change In Payable': -29000000.0,
#    'Change In Account Payable': -29000000.0,
#    'Change In Prepaid Assets': -24000000.0,
#    'Change In Inventory': -2436000000.0,
#    'Change In Receivables': 5327000000.0,
#    'Changes In Account Receivables': 5327000000.0,
#    'Other Non Cash Items': 1074000000.0,
#    'Stock Based Compensation': 3128000000.0,
#    'Asset Impairment Charge': 301000000.0,
#    'Deferred Tax': -5148000000.0,
#    'Deferred Income Tax': -5148000000.0,
#    'Depreciation Amortization Depletion': 13035000000.0,
#    'Depreciation And Amortization': 13035000000.0,
#    'Amortization Cash Flow': 1907000000.0,
#    'Amortization Of Intangibles': 1907000000.0,
#    'Depreciation': 11128000000.0,
#    'Operating Gains Losses': -5313000000.0,
#    'Gain Loss On Investment Securities': -4254000000.0,
#    'Gain Loss On Sale Of Business': -1059000000.0,
#    'Net Income From Continuing Operations': 8017000000.0},
#   Timestamp('2021-12-31 00:00:00'): {'Free Cash Flow': nan,
#    'Repurchase Of Capital Stock': -2415000000.0,
#    'Repayment Of Debt': nan,
#    'Issuance Of Debt': nan,
#    'Issuance Of Capital Stock': 0.0,
#    'Capital Expenditure': nan,
#    'Interest Paid Supplemental Data': nan,
#    'Income Tax Paid Supplemental Data': nan,
#    'End Cash Position': nan,
#    'Beginning Cash Position': nan,
#    'Changes In Cash': nan,
#    'Financing Cash Flow': nan,
#    'Cash Flow From Continuing Financing Activities': nan,
#    'Net Other Financing Charges': nan,
#    'Proceeds From Stock Option Exercised': nan,
#    'Cash Dividends Paid': nan,
#    'Common Stock Dividend Paid': nan,
#    'Net Common Stock Issuance': -2415000000.0,
#    'Common Stock Payments': -2415000000.0,
#    'Common Stock Issuance': 0.0,
#    'Net Issuance Payments Of Debt': nan,
#    'Net Short Term Debt Issuance': nan,
#    'Short Term Debt Payments': nan,
#    'Short Term Debt Issuance': nan,
#    'Net Long Term Debt Issuance': nan,
#    'Long Term Debt Payments': nan,
#    'Long Term Debt Issuance': nan,
#    'Investing Cash Flow': nan,
#    'Cash Flow From Continuing Investing Activities': nan,
#    'Net Other Investing Changes': nan,
#    'Net Investment Purchase And Sale': nan,
#    'Sale Of Investment': nan,
#    'Purchase Of Investment': nan,
#    'Net Business Purchase And Sale': nan,
#    'Sale Of Business': nan,
#    'Purchase Of Business': -209000000.0,
#    'Net PPE Purchase And Sale': nan,
#    'Purchase Of PPE': nan,
#    'Operating Cash Flow': nan,
#    'Cash Flow From Continuing Operating Activities': nan,
#    'Change In Working Capital': nan,
#    'Change In Other Working Capital': nan,
#    'Change In Payables And Accrued Expense': nan,
#    'Change In Accrued Expense': nan,
#    'Change In Payable': nan,
#    'Change In Account Payable': nan,
#    'Change In Prepaid Assets': -1583000000.0,
#    'Change In Inventory': nan,
#    'Change In Receivables': nan,
#    'Changes In Account Receivables': nan,
#    'Other Non Cash Items': nan,
#    'Stock Based Compensation': nan,
#    'Asset Impairment Charge': nan,
#    'Deferred Tax': nan,
#    'Deferred Income Tax': nan,
#    'Depreciation Amortization Depletion': nan,
#    'Depreciation And Amortization': nan,
#    'Amortization Cash Flow': nan,
#    'Amortization Of Intangibles': nan,
#    'Depreciation': nan,
#    'Operating Gains Losses': nan,
#    'Gain Loss On Investment Securities': nan,
#    'Gain Loss On Sale Of Business': nan,
#    'Net Income From Continuing Operations': nan}}}

# %%
client.get_dividends("AAPL")
# Out:
# [{'date': '1987-05-11', 'dividend': 0.000536},
#  {'date': '1987-08-10', 'dividend': 0.000536},
#  {'date': '1987-11-17', 'dividend': 0.000714},
#  {'date': '1988-02-12', 'dividend': 0.000714},
#  {'date': '1988-05-16', 'dividend': 0.000714},
#  {'date': '1988-08-15', 'dividend': 0.000714},
#  {'date': '1988-11-21', 'dividend': 0.000893},
#  {'date': '1989-02-17', 'dividend': 0.000893},
#  {'date': '1989-05-22', 'dividend': 0.000893},
#  {'date': '1989-08-21', 'dividend': 0.000893},
#  {'date': '1989-11-17', 'dividend': 0.000982},
#  {'date': '1990-02-16', 'dividend': 0.000982},
#  {'date': '1990-05-21', 'dividend': 0.000982},
#  {'date': '1990-08-20', 'dividend': 0.000982},
#  {'date': '1990-11-16', 'dividend': 0.001071},
#  {'date': '1991-02-15', 'dividend': 0.001071},
#  {'date': '1991-05-20', 'dividend': 0.001071},
#  {'date': '1991-08-19', 'dividend': 0.001071},
#  {'date': '1991-11-18', 'dividend': 0.001071},
#  {'date': '1992-02-14', 'dividend': 0.001071},
#  {'date': '1992-06-01', 'dividend': 0.001071},
#  {'date': '1992-08-17', 'dividend': 0.001071},
#  {'date': '1992-11-30', 'dividend': 0.001071},
#  {'date': '1993-02-12', 'dividend': 0.001071},
#  {'date': '1993-05-28', 'dividend': 0.001071},
#  {'date': '1993-08-16', 'dividend': 0.001071},
#  {'date': '1993-11-19', 'dividend': 0.001071},
#  {'date': '1994-02-07', 'dividend': 0.001071},
#  {'date': '1994-05-27', 'dividend': 0.001071},
#  {'date': '1994-08-15', 'dividend': 0.001071},
#  {'date': '1994-11-18', 'dividend': 0.001071},
#  {'date': '1995-02-13', 'dividend': 0.001071},
#  {'date': '1995-05-26', 'dividend': 0.001071},
#  {'date': '1995-08-16', 'dividend': 0.001071},
#  {'date': '1995-11-21', 'dividend': 0.001071},
#  {'date': '2012-08-09', 'dividend': 0.094643},
#  {'date': '2012-11-07', 'dividend': 0.094643},
#  {'date': '2013-02-07', 'dividend': 0.094643},
#  {'date': '2013-05-09', 'dividend': 0.108929},
#  {'date': '2013-08-08', 'dividend': 0.108929},
#  {'date': '2013-11-06', 'dividend': 0.108929},
#  {'date': '2014-02-06', 'dividend': 0.108929},
#  {'date': '2014-05-08', 'dividend': 0.1175},
#  {'date': '2014-08-07', 'dividend': 0.1175},
#  {'date': '2014-11-06', 'dividend': 0.1175},
#  {'date': '2015-02-05', 'dividend': 0.1175},
#  {'date': '2015-05-07', 'dividend': 0.13},
#  {'date': '2015-08-06', 'dividend': 0.13},
#  {'date': '2015-11-05', 'dividend': 0.13},
#  {'date': '2016-02-04', 'dividend': 0.13},
#  {'date': '2016-05-05', 'dividend': 0.1425},
#  {'date': '2016-08-04', 'dividend': 0.1425},
#  {'date': '2016-11-03', 'dividend': 0.1425},
#  {'date': '2017-02-09', 'dividend': 0.1425},
#  {'date': '2017-05-11', 'dividend': 0.1575},
#  {'date': '2017-08-10', 'dividend': 0.1575},
#  {'date': '2017-11-10', 'dividend': 0.1575},
#  {'date': '2018-02-09', 'dividend': 0.1575},
#  {'date': '2018-05-11', 'dividend': 0.1825},
#  {'date': '2018-08-10', 'dividend': 0.1825},
#  {'date': '2018-11-08', 'dividend': 0.1825},
#  {'date': '2019-02-08', 'dividend': 0.1825},
#  {'date': '2019-05-10', 'dividend': 0.1925},
#  {'date': '2019-08-09', 'dividend': 0.1925},
#  {'date': '2019-11-07', 'dividend': 0.1925},
#  {'date': '2020-02-07', 'dividend': 0.1925},
#  {'date': '2020-05-08', 'dividend': 0.205},
#  {'date': '2020-08-07', 'dividend': 0.205},
#  {'date': '2020-11-06', 'dividend': 0.205},
#  {'date': '2021-02-05', 'dividend': 0.205},
#  {'date': '2021-05-07', 'dividend': 0.22},
#  {'date': '2021-08-06', 'dividend': 0.22},
#  {'date': '2021-11-05', 'dividend': 0.22},
#  {'date': '2022-02-04', 'dividend': 0.22},
#  {'date': '2022-05-06', 'dividend': 0.23},
#  {'date': '2022-08-05', 'dividend': 0.23},
#  {'date': '2022-11-04', 'dividend': 0.23},
#  {'date': '2023-02-10', 'dividend': 0.23},
#  {'date': '2023-05-12', 'dividend': 0.24},
#  {'date': '2023-08-11', 'dividend': 0.24},
#  {'date': '2023-11-10', 'dividend': 0.24},
#  {'date': '2024-02-09', 'dividend': 0.24},
#  {'date': '2024-05-10', 'dividend': 0.25},
#  {'date': '2024-08-12', 'dividend': 0.25},
#  {'date': '2024-11-08', 'dividend': 0.25},
#  {'date': '2025-02-10', 'dividend': 0.25},
#  {'date': '2025-05-12', 'dividend': 0.26},
#  {'date': '2025-08-11', 'dividend': 0.26},
#  {'date': '2025-11-10', 'dividend': 0.26},
#  {'date': '2026-02-09', 'dividend': 0.26}]

# %%
client.cache_stats()
# Out:
# {'total_entries': 11, 'alive': 11, 'expired': 0}
