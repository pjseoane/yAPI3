# %%
import yfinance_api3.modules.portfolio as portfolio

from yfinance_api3.classes.stock_client import StockClient
from yfinance_api3.classes.quant_analytics import QuantAnalytics as qa
import yfinance_api3.modules.plots as plots

client = StockClient(ttl_price=60, ttl_info=900)
quant = qa(client)

# %%
symbols = ["AAPL", "MSFT", "NVDA", "GOOGL", "JPM", "JNJ", "AMZN"]

# %%
ew  = portfolio.equal_weight(quant, symbols)
ew
# Out:
# PortfolioResult — Equal weight
#   Return     : 31.04%
#   Volatility : 18.34%
#   Sharpe     : 1.420
#   Weights:
#     AAPL: 14.29%
#     MSFT: 14.29%
#     NVDA: 14.29%
#     GOOGL: 14.29%
#     JPM: 14.29%
#     JNJ: 14.29%
#     AMZN: 14.29%

# %%
mv  = portfolio.min_variance(quant, symbols)
mv
# Out:
# PortfolioResult — Min variance
#   Return     : 19.11%
#   Volatility : 12.12%
#   Sharpe     : 1.164
#   Weights:
#     JNJ: 53.67%
#     MSFT: 19.19%
#     JPM: 13.12%
#     GOOGL: 5.75%
#     AAPL: 4.39%
#     AMZN: 2.16%
#     NVDA: 1.72%

# %%
ms  = portfolio.max_sharpe(quant, symbols)
ms
# Out:
# PortfolioResult — Max Sharpe
#   Return     : 33.59%
#   Volatility : 15.86%
#   Sharpe     : 1.802
#   Weights:
#     JNJ: 39.56%
#     NVDA: 20.38%
#     GOOGL: 20.35%
#     JPM: 19.71%
#     AMZN: 0.00%
#     MSFT: 0.00%
#     AAPL: 0.00%

# %%
rp  = portfolio.risk_parity(quant, symbols)

# %%
# compare all strategies in one table
df = portfolio.compare_strategies(quant, symbols)
print(df.to_string(float_format="{:.2%}".format))
# Out:
#               expected_return  volatility  sharpe_ratio   AAPL   MSFT   NVDA  GOOGL    JPM    JNJ   AMZN
# Equal weight           31.04%      18.34%       141.99% 14.29% 14.29% 14.29% 14.29% 14.29% 14.29% 14.29%
# Min variance           19.11%      12.12%       116.43%  4.39% 19.19%  1.72%  5.75% 13.12% 53.67%  2.16%
# Max Sharpe             33.59%      15.86%       180.23%  0.00%  0.00% 20.38% 20.35% 19.71% 39.56%  0.00%
# Risk parity            24.99%      13.82%       144.56% 11.42% 12.75%  7.11% 10.34% 14.41% 34.63%  9.34%

# %%
frontier = portfolio.efficient_frontier(quant, symbols, period="3y", n_points=60)
plots.efficient_frontier(frontier).show()

# %%
weights = ms.weights.tolist()
weights
# Out:
# [0.0,
#  3.821394549705538e-17,
#  0.20380865115273777,
#  0.20346860691600718,
#  0.19708102397916497,
#  0.39564171795209013,
#  6.832522914896467e-17]

# %%
quant.portfolio_summary(symbols, weights, period="3y")
# Out:
# {'symbols': ['AAPL', 'MSFT', 'NVDA', 'GOOGL', 'JPM', 'JNJ', 'AMZN'],
#  'weights': [0.0,
#   3.821394549705538e-17,
#   0.20380865115273777,
#   0.20346860691600718,
#   0.19708102397916497,
#   0.39564171795209013,
#   6.832522914896467e-17],
#  'period': '3y',
#  'annualised_return': 0.3358852751036168,
#  'annualised_volatility': 0.15862660365804634,
#  'sharpe_ratio': 1.8022530175323166,
#  'correlation_matrix': {'AAPL': {'AAPL': 1.0,
#    'MSFT': 0.41912413254748127,
#    'NVDA': 0.35620821104060607,
#    'GOOGL': 0.4303444385528341,
#    'JPM': 0.31588215577009565,
#    'JNJ': 0.045868552550312226,
#    'AMZN': 0.43559655928715374},
#   'MSFT': {'AAPL': 0.41912413254748127,
#    'MSFT': 1.0,
#    'NVDA': 0.5054685747731451,
#    'GOOGL': 0.4200249203788054,
#    'JPM': 0.26102290909507575,
#    'JNJ': -0.1265095286863076,
#    'AMZN': 0.5525383722065405},
#   'NVDA': {'AAPL': 0.35620821104060607,
#    'MSFT': 0.5054685747731451,
#    'NVDA': 1.0,
#    'GOOGL': 0.4067481739912075,
#    'JPM': 0.2669080787884986,
#    'JNJ': -0.24894935986099556,
#    'AMZN': 0.45518469642556375},
#   'GOOGL': {'AAPL': 0.4303444385528341,
#    'MSFT': 0.4200249203788054,
#    'NVDA': 0.4067481739912075,
#    'GOOGL': 1.0,
#    'JPM': 0.2604789670120147,
#    'JNJ': -0.057235148679653874,
#    'AMZN': 0.5475823782807007},
#   'JPM': {'AAPL': 0.31588215577009565,
#    'MSFT': 0.26102290909507575,
#    'NVDA': 0.2669080787884986,
#    'GOOGL': 0.2604789670120147,
#    'JPM': 1.0,
#    'JNJ': 0.11535928971653285,
#    'AMZN': 0.3330391889337725},
#   'JNJ': {'AAPL': 0.045868552550312226,
#    'MSFT': -0.1265095286863076,
#    'NVDA': -0.24894935986099556,
#    'GOOGL': -0.057235148679653874,
#    'JPM': 0.11535928971653285,
#    'JNJ': 1.0,
#    'AMZN': -0.13977435025760704},
#   'AMZN': {'AAPL': 0.43559655928715374,
#    'MSFT': 0.5525383722065405,
#    'NVDA': 0.45518469642556375,
#    'GOOGL': 0.5475823782807007,
#    'JPM': 0.3330391889337725,
#    'JNJ': -0.13977435025760704,
#    'AMZN': 1.0}}}
