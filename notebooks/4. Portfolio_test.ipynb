# %%
# put this at the top of every notebook
import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %%
import yfinance_api3.modules.portfolio as portfolio

from yfinance_api3.classes.stock_client import StockClient
from yfinance_api3.classes.quant_analytics import QuantAnalytics as qa
import yfinance_api3.modules.plots as plots

client = StockClient(ttl_price=60, ttl_info=900)
quant = qa(client)

# %%
symbols = ["AAPL", "MSFT", "NVDA", "GOOGL", "JPM", "JNJ", "AMZN"]

# %%
ew  = portfolio.equal_weight(quant, symbols)
ew
# Out:
# PortfolioResult — Equal weight
#   Return     : 31.04%
#   Volatility : 18.34%
#   Sharpe     : 1.420
#   Weights:
#     AAPL: 14.29%
#     MSFT: 14.29%
#     NVDA: 14.29%
#     GOOGL: 14.29%
#     JPM: 14.29%
#     JNJ: 14.29%
#     AMZN: 14.29%

# %%
mv  = portfolio.min_variance(quant, symbols)
mv
# Out:
# PortfolioResult — Min variance
#   Return     : 19.11%
#   Volatility : 12.12%
#   Sharpe     : 1.164
#   Weights:
#     JNJ: 53.67%
#     MSFT: 19.19%
#     JPM: 13.12%
#     GOOGL: 5.75%
#     AAPL: 4.39%
#     AMZN: 2.16%
#     NVDA: 1.72%

# %%
ms  = portfolio.max_sharpe(quant, symbols)
ms
# Out:
# PortfolioResult — Max Sharpe
#   Return     : 33.59%
#   Volatility : 15.86%
#   Sharpe     : 1.802
#   Weights:
#     JNJ: 39.56%
#     NVDA: 20.38%
#     GOOGL: 20.35%
#     JPM: 19.71%
#     AAPL: 0.00%
#     AMZN: 0.00%
#     MSFT: 0.00%

# %%
rp  = portfolio.risk_parity(quant, symbols)

# %%
# compare all strategies in one table
df = portfolio.compare_strategies(quant, symbols)
print(df.to_string(float_format="{:.2%}".format))
# Out:
#               expected_return  volatility  sharpe_ratio   AAPL   MSFT   NVDA  GOOGL    JPM    JNJ   AMZN
# Equal weight           31.04%      18.34%       141.99% 14.29% 14.29% 14.29% 14.29% 14.29% 14.29% 14.29%
# Min variance           19.11%      12.12%       116.43%  4.39% 19.19%  1.72%  5.75% 13.12% 53.67%  2.16%
# Max Sharpe             33.59%      15.86%       180.23%  0.00%  0.00% 20.38% 20.35% 19.71% 39.56%  0.00%
# Risk parity            24.99%      13.82%       144.56% 11.42% 12.75%  7.11% 10.34% 14.41% 34.63%  9.34%

# %%
frontier = portfolio.efficient_frontier(quant, symbols, period="3y", n_points=60)
plots.efficient_frontier(frontier).show()
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="e28b99be-826b-42df-807b-526e0ae8b7a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e28b99be-826b-42df-807b-526e0ae8b7a0")) {                    Plotly.newPlot(                        "e28b99be-826b-42df-807b-526e0ae8b7a0",                        [{"customdata":{"dtype":"f8","bdata":"t19Bvgh2yD9odvqt7KDyP5wnGPyZjck\u002fxtLqYuy78z9I7e45K6XKPxO6wBsay\u002fQ\u002fSbTFd7y8yz+1NR26+sz1P3N9nLVN1Mw\u002fbL7ZNlvA9j+NQnPz3uvNP8Jw+W5WpPc\u002fP+NJMXADzz+pgvEDNHj4P3yFkLeADdA\u002f4+zFcbk6+T8M6XtWSZnQP5hl4hy66\u002fk\u002fnUxn9REl0T+a2GdQgov6P5p4UpTasNE\u002fO9rE\u002fZ0a+z9l9z0zozzSP87YTbVtmfs\u002f+Vcp0mvI0j8saQVwIwL8PxPAFHE0VNM\u002fKtpng+9T\u002fD+AIgAQ\u002fd\u002fTP1q7hjbHkPw\u002fzITrrsVr1D+gaKlrObn8P1zo1k2O99Q\u002fKYDvB3DP\u002fD\u002fkTMLsVoPVP
lhYJMf+T+p9vQnxPH4P2w43n5ow\u002fg\u002foOMYkMqU+D+Fw2+HKGb4P8dsTSC2N\u002fg\u002f+\u002f\u002fdDZ4J+D\u002fynpU8A9z3P8VJoO4Br\u002fc\u002fc\u002fRbU2+C9z8XoBZjLVT3Pwh\u002fuYgoJPc\u002frxPsIdby9j+PdjU4nMD2P+W0Rs\u002fSjfY\u002fHBiTPcVa9j8lbBGBsyf2P2MjWobT9PU\u002f6C7KW1LC9T+1ovlMVZD1P31PzuT6XvU\u002f"},"colorbar":{"len":0.6,"outlinewidth":0,"thickness":12,"tickfont":{"color":"#888780","size":9},"title":{"text":"Sharpe"}},"colorscale":[[0.0,"rgb(165,0,38)"],[0.1,"rgb(215,48,39)"],[0.2,"rgb(244,109,67)"],[0.3,"rgb(253,174,97)"],[0.4,"rgb(254,224,139)"],[0.5,"rgb(255,255,191)"],[0.6,"rgb(217,239,139)"],[0.7,"rgb(166,217,106)"],[0.8,"rgb(102,189,99)"],[0.9,"rgb(26,152,80)"],[1.0,"rgb(0,104,55)"]],"showscale":true,"size":6},"mode":"lines+markers","showlegend":false,"x":{"dtype":"f8","bdata":"xiWOBmwGvz8idO6k1g6\u002fP3 ...

# %%
weights = ms.weights.tolist()
weights
# Out:
# [1.6283087532044742e-16,
#  0.0,
#  0.20380868568460941,
#  0.20346863299415377,
#  0.19708136271900456,
#  0.395641318602232,
#  4.172746500996247e-17]

# %%
quant.portfolio_summary(symbols, weights, period="3y")
# Out:
# {'symbols': ['AAPL', 'MSFT', 'NVDA', 'GOOGL', 'JPM', 'JNJ', 'AMZN'],
#  'weights': [1.6283087532044742e-16,
#   0.0,
#   0.20380868568460941,
#   0.20346863299415377,
#   0.19708136271900456,
#   0.395641318602232,
#   4.172746500996247e-17],
#  'period': '3y',
#  'annualised_return': 0.33588536252850265,
#  'annualised_volatility': 0.15862665949125562,
#  'sharpe_ratio': 1.8022529343137446,
#  'correlation_matrix': {'AAPL': {'AAPL': 1.0,
#    'MSFT': 0.4191239157307621,
#    'NVDA': 0.35620797698532003,
#    'GOOGL': 0.43034453472068035,
#    'JPM': 0.3158823535857021,
#    'JNJ': 0.045869153941270585,
#    'AMZN': 0.43559664292389966},
#   'MSFT': {'AAPL': 0.4191239157307621,
#    'MSFT': 1.0,
#    'NVDA': 0.5054687771576364,
#    'GOOGL': 0.42002542366874446,
#    'JPM': 0.2610234378497236,
#    'JNJ': -0.12650871127224073,
#    'AMZN': 0.5525381474693836},
#   'NVDA': {'AAPL': 0.35620797698532003,
#    'MSFT': 0.5054687771576364,
#    'NVDA': 1.0,
#    'GOOGL': 0.4067483444303839,
#    'JPM': 0.26690826418918306,
#    'JNJ': -0.24894943020106114,
#    'AMZN': 0.4551847646318491},
#   'GOOGL': {'AAPL': 0.43034453472068035,
#    'MSFT': 0.42002542366874446,
#    'NVDA': 0.4067483444303839,
#    'GOOGL': 1.0,
#    'JPM': 0.2604793022237297,
#    'JNJ': -0.05723483905314239,
#    'AMZN': 0.5475824719305615},
#   'JPM': {'AAPL': 0.3158823535857021,
#    'MSFT': 0.2610234378497236,
#    'NVDA': 0.26690826418918306,
#    'GOOGL': 0.2604793022237297,
#    'JPM': 1.0,
#    'JNJ': 0.11535941104627347,
#    'AMZN': 0.333039443116039},
#   'JNJ': {'AAPL': 0.045869153941270585,
#    'MSFT': -0.12650871127224073,
#    'NVDA': -0.24894943020106114,
#    'GOOGL': -0.05723483905314239,
#    'JPM': 0.11535941104627347,
#    'JNJ': 1.0,
#    'AMZN': -0.1397741594260836},
#   'AMZN': {'AAPL': 0.43559664292389966,
#    'MSFT': 0.5525381474693836,
#    'NVDA': 0.4551847646318491,
#    'GOOGL': 0.5475824719305615,
#    'JPM': 0.333039443116039,
#    'JNJ': -0.1397741594260836,
#    'AMZN': 1.0}}}
