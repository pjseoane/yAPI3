# %%
# put this at the top of every notebook
import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %%
from yfinance_api3.classes.stock_client import StockClient
from yfinance_api3.classes.quant_analytics import QuantAnalytics as qa
import yfinance_api3.modules.plots as plots

# %%
client = StockClient(ttl_price=60, ttl_info=900)
quant = qa(client)

# %%
# main analysis table
df = quant.best_worst_days_impact("SPY", period="20y")
print(df[["scenario", "final_value", "total_return", "cagr"]].to_string())

# see exactly when the extreme days happened
detail = quant.best_worst_days_detail("SPY", period="20y", n=20)
print(detail)   # sorted best→worst, dates show they cluster around crises
# Out:
#               scenario   final_value  total_return      cagr
# 0           Buy & Hold  7.890430e+04      6.890430  0.108987
# 1     Miss best 5 days  4.715871e+04      3.715871  0.080766
# 2    Miss best 10 days  3.423791e+04      2.423791  0.063574
# 3    Miss best 20 days  2.059353e+04      1.059353  0.036839
# 4    Miss best 30 days  1.367688e+04      0.367688  0.015805
# 5    Miss best 40 days  9.526690e+03     -0.047331 -0.002425
# 6    Miss best 50 days  6.853516e+03     -0.314648 -0.018743
# 7    Miss worst 5 days  1.293705e+05     11.937048  0.136790
# 8   Miss worst 10 days  1.862496e+05     17.624958  0.157726
# 9   Miss worst 20 days  3.211901e+05     31.119009  0.189756
# 10  Miss worst 30 days  5.132325e+05     50.323253  0.218012
# 11  Miss worst 40 days  7.949909e+05     78.499094  0.244999
# 12  Miss worst 50 days  1.170557e+06    116.055732  0.269358
#            date    return   type
# rank
# 1    2008-10-13  0.145198   best
# 2    2008-10-28  0.116855   best
# ...

# %%
df
# Out:
#               scenario  days_missed   final_value  total_return      cagr  \
# 0           Buy & Hold            0  7.890430e+04      6.890430  0.108987
# 1     Miss best 5 days            5  4.715871e+04      3.715871  0.080766
# 2    Miss best 10 days           10  3.423791e+04      2.423791  0.063574
# 3    Miss best 20 days           20  2.059353e+04      1.059353  0.036839
# 4    Miss best 30 days           30  1.367688e+04      0.367688  0.015805
# 5    Miss best 40 days           40  9.526690e+03     -0.047331 -0.002425
# 6    Miss best 50 days           50  6.853516e+03     -0.314648 -0.018743
# 7    Miss worst 5 days            5  1.293705e+05     11.937048  0.136790
# 8   Miss worst 10 days           10  1.862496e+05     17.624958  0.157726
# 9   Miss worst 20 days           20  3.211901e+05     31.119009  0.189756
# 10  Miss worst 30 days           30  5.132325e+05     50.323253  0.218012
# 11  Miss worst 40 days           40  7.949909e+05     78.499094  0.244999
# ...

# %%
plots.best_worst_days(quant, "SPY", period="20y").show()

# custom scenarios
plots.best_worst_days(quant, "SPY",
                      miss_scenarios=[1, 5, 10, 20, 50],
                      initial_value=100_000).show()

# works for any stock/ETF
plots.best_worst_days(quant, "QQQ", period="20y").show()
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Concentration of Good / Bad days

# %%
plots.extreme_days_concentration(quant, "SPY", period="20y").show()

# zoom in on fewer extreme days
plots.extreme_days_concentration(quant, "SPY", period="20y", n=20).show()

# shorter window for density (monthly instead of quarterly)
plots.extreme_days_concentration(quant, "SPY", n=50, window=21).show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
detail = quant.best_worst_days_detail("SPY", period="20y", n=20)
print(detail.dtypes)
print(detail["date"].head())
print(type(detail["date"].iloc[0]))
# Out:
# date      datetime64[s]
# return          float64
# type                str
# dtype: object
# rank
# 1   2008-10-13
# 2   2008-10-28
# 3   2025-04-09
# 4   2020-03-24
# 5   2020-03-13
# Name: date, dtype: datetime64[s]
# <class 'pandas.Timestamp'>

# %%
df = quant.best_worst_days_impact("SPY", period="20y")
print(df)
print("\nTypes:", df.dtypes)
# Out:
#               scenario  days_missed   final_value  total_return      cagr  \
# 0           Buy & Hold            0  7.890430e+04      6.890430  0.108987
# 1     Miss best 5 days            5  4.715871e+04      3.715871  0.080766
# 2    Miss best 10 days           10  3.423791e+04      2.423791  0.063574
# 3    Miss best 20 days           20  2.059353e+04      1.059353  0.036839
# 4    Miss best 30 days           30  1.367688e+04      0.367688  0.015805
# 5    Miss best 40 days           40  9.526690e+03     -0.047331 -0.002425
# 6    Miss best 50 days           50  6.853516e+03     -0.314648 -0.018743
# 7    Miss worst 5 days            5  1.293705e+05     11.937048  0.136790
# 8   Miss worst 10 days           10  1.862496e+05     17.624958  0.157726
# 9   Miss worst 20 days           20  3.211901e+05     31.119009  0.189756
# 10  Miss worst 30 days           30  5.132325e+05     50.323253  0.218012
# 11  Miss worst 40 days           40  7.949909e+05     78.499094  0.244999
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

detail = quant.best_worst_days_detail("SPY", period="20y", n=20)
best  = detail[detail["type"] == "best"]
worst = detail[detail["type"] == "worst"]

# test panel 2 in isolation
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=best["date"],
    y=best["return"],
    mode="markers",
    name="Best"
))
fig.add_trace(go.Scatter(
    x=worst["date"],
    y=worst["return"],
    mode="markers",
    name="Worst"
))
fig.update_xaxes(type="date")
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
