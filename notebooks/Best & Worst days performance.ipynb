# %%
from classes.stock_client import StockClient
from classes.quant_analytics import QuantAnalytics as qa
import modules.plots as plots

# %%
client = StockClient(ttl_price=60, ttl_info=900)
quant = qa(client)

# %%
# main analysis table
df = quant.best_worst_days_impact("SPY", period="20y")
print(df[["scenario", "final_value", "total_return", "cagr"]].to_string())

# see exactly when the extreme days happened
detail = quant.best_worst_days_detail("SPY", period="20y", n=20)
print(detail)   # sorted best→worst, dates show they cluster around crises
# Out:
#               scenario   final_value  total_return      cagr
# 0           Buy & Hold  7.829753e+04      6.829753  0.108581
# 1     Miss best 5 days  4.679611e+04      3.679611  0.080365
# 2    Miss best 10 days  3.397463e+04      2.397463  0.063176
# 3    Miss best 20 days  2.043515e+04      1.043515  0.036446
# 4    Miss best 30 days  1.357171e+04      0.357171  0.015415
# 5    Miss best 40 days  9.453439e+03     -0.054656 -0.002811
# 6    Miss best 50 days  6.800810e+03     -0.319919 -0.019126
# 7    Miss worst 5 days  1.283756e+05     11.837564  0.136379
# 8   Miss worst 10 days  1.848174e+05     17.481743  0.157312
# 9   Miss worst 20 days  3.187205e+05     30.872051  0.189337
# 10  Miss worst 30 days  5.092855e+05     49.928553  0.217589
# 11  Miss worst 40 days  7.888782e+05     77.887825  0.244572
# 12  Miss worst 50 days  1.161557e+06    115.155660  0.268927
#            date    return   type
# rank
# 1    2008-10-13  0.145197   best
# 2    2008-10-28  0.116855   best
# 3    2025-04-09  0.105019   best
# 4    2020-03-24  0.090603   best
# 5    2020-03-13  0.085486   best
# 6    2009-03-23  0.071829   best
# 7    2008-11-24  0.069290   best
# 8    2020-04-06  0.067166   best
# 9    2008-11-13  0.062340   best
# 10   2008-10-20  0.060079   best
# 11   2009-03-10  0.059609   best
# 12   2020-03-26  0.058390   best
# 13   2022-11-10  0.054954   best
# 14   2020-03-17  0.053992   best
# 15   2008-11-21  0.053943   best
# 16   2020-03-10  0.051745   best
# 17   2018-12-26  0.050525   best
# 18   2008-12-16  0.047066   best
# 19   2011-08-09  0.046499   best
# 20   2011-08-11  0.044884   best
# 21   2025-04-03 -0.049281  worst
# 22   2008-11-14 -0.049907  worst
# 23   2020-03-18 -0.050633  worst
# 24   2008-10-24 -0.050714  worst
# 25   2008-10-06 -0.050933  worst
# 26   2009-01-20 -0.052786  worst
# 27   2008-10-22 -0.054455  worst
# 28   2008-11-06 -0.055411  worst
# 29   2020-06-11 -0.057649  worst
# 30   2025-04-04 -0.058543  worst
# 31   2008-11-19 -0.064079  worst
# 32   2011-08-08 -0.065123  worst
# 33   2008-10-09 -0.069839  worst
# 34   2008-11-20 -0.074233  worst
# 35   2020-03-09 -0.078095  worst
# 36   2008-09-29 -0.078361  worst
# 37   2008-12-01 -0.088578  worst
# 38   2020-03-12 -0.095677  worst
# 39   2008-10-15 -0.098448  worst
# 40   2020-03-16 -0.109424  worst

# %%
df
# Out:
#               scenario  days_missed   final_value  total_return      cagr  \
# 0           Buy & Hold            0  7.829753e+04      6.829753  0.108581
# 1     Miss best 5 days            5  4.679611e+04      3.679611  0.080365
# 2    Miss best 10 days           10  3.397463e+04      2.397463  0.063176
# 3    Miss best 20 days           20  2.043515e+04      1.043515  0.036446
# 4    Miss best 30 days           30  1.357171e+04      0.357171  0.015415
# 5    Miss best 40 days           40  9.453439e+03     -0.054656 -0.002811
# 6    Miss best 50 days           50  6.800810e+03     -0.319919 -0.019126
# 7    Miss worst 5 days            5  1.283756e+05     11.837564  0.136379
# 8   Miss worst 10 days           10  1.848174e+05     17.481743  0.157312
# 9   Miss worst 20 days           20  3.187205e+05     30.872051  0.189337
# 10  Miss worst 30 days           30  5.092855e+05     49.928553  0.217589
# 11  Miss worst 40 days           40  7.888782e+05     77.887825  0.244572
# 12  Miss worst 50 days           50  1.161557e+06    115.155660  0.268927
#
#      vs_buy_hold          type symbol period  n_trading_days  initial_value
# 0   0.000000e+00  buy_and_hold    SPY    20y            5031        10000.0
# 1  -3.150143e+04     miss_best    SPY    20y            5031        10000.0
# 2  -4.432290e+04     miss_best    SPY    20y            5031        10000.0
# 3  -5.786238e+04     miss_best    SPY    20y            5031        10000.0
# 4  -6.472582e+04     miss_best    SPY    20y            5031        10000.0
# 5  -6.884409e+04     miss_best    SPY    20y            5031        10000.0
# 6  -7.149672e+04     miss_best    SPY    20y            5031        10000.0
# 7   5.007811e+04    miss_worst    SPY    20y            5031        10000.0
# 8   1.065199e+05    miss_worst    SPY    20y            5031        10000.0
# 9   2.404230e+05    miss_worst    SPY    20y            5031        10000.0
# 10  4.309880e+05    miss_worst    SPY    20y            5031        10000.0
# 11  7.105807e+05    miss_worst    SPY    20y            5031        10000.0
# 12  1.083259e+06    miss_worst    SPY    20y            5031        10000.0

# %%
plots.best_worst_days(quant, "SPY", period="20y").show()

# custom scenarios
plots.best_worst_days(quant, "SPY",
    miss_scenarios=[1, 5, 10, 20, 50],
    initial_value=100_000).show()

# works for any stock/ETF
plots.best_worst_days(quant, "QQQ", period="20y").show()

# %% [markdown]
# ## Concentration of Good / Bad days

# %%
plots.extreme_days_concentration(quant, "SPY", period="20y").show()

# zoom in on fewer extreme days
plots.extreme_days_concentration(quant, "SPY", period="20y", n=20).show()

# shorter window for density (monthly instead of quarterly)
plots.extreme_days_concentration(quant, "SPY", n=50, window=21).show()
