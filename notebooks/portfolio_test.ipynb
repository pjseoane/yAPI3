# %%
import modules.portfolio as portfolio

from classes.stock_client import StockClient
from classes.quant_analytics import QuantAnalytics as qa
import modules.plots as plots

client = StockClient(ttl_price=60, ttl_info=900)
quant = qa(client)

# %%
symbols = ["AAPL", "MSFT", "NVDA", "GOOGL", "JPM", "JNJ", "AMZN"]

# %%
ew  = portfolio.equal_weight(quant, symbols)
ew
# Out:
# PortfolioResult — Equal weight
#   Return     : 30.16%
#   Volatility : 18.34%
#   Sharpe     : 1.372
#   Weights:
#     AAPL: 14.29%
#     MSFT: 14.29%
#     NVDA: 14.29%
#     GOOGL: 14.29%
#     JPM: 14.29%
#     JNJ: 14.29%
#     AMZN: 14.29%

# %%
mv  = portfolio.min_variance(quant, symbols)
mv
# Out:
# PortfolioResult — Min variance
#   Return     : 19.56%
#   Volatility : 12.09%
#   Sharpe     : 1.204
#   Weights:
#     JNJ: 53.93%
#     MSFT: 18.90%
#     JPM: 12.88%
#     GOOGL: 5.90%
#     AAPL: 4.56%
#     AMZN: 2.08%
#     NVDA: 1.75%

# %%
ms  = portfolio.max_sharpe(quant, symbols)
ms
# Out:
# PortfolioResult — Max Sharpe
#   Return     : 30.87%
#   Volatility : 14.41%
#   Sharpe     : 1.795
#   Weights:
#     JNJ: 47.26%
#     GOOGL: 18.63%
#     JPM: 17.51%
#     NVDA: 16.61%
#     MSFT: 0.00%
#     AMZN: 0.00%
#     AAPL: 0.00%

# %%
rp  = portfolio.risk_parity(quant, symbols)

# %%
# compare all strategies in one table
df = portfolio.compare_strategies(quant, symbols)
print(df.to_string(float_format="{:.2%}".format))
# Out:
#               expected_return  volatility  sharpe_ratio   AAPL   MSFT   NVDA  GOOGL    JPM    JNJ   AMZN
# Equal weight           30.16%      18.34%       137.17% 14.29% 14.29% 14.29% 14.29% 14.29% 14.29% 14.29%
# Min variance           19.56%      12.09%       120.38%  4.56% 18.90%  1.75%  5.90% 12.88% 53.93%  2.08%
# Max Sharpe             30.87%      14.41%       179.52%  0.00%  0.00% 16.61% 18.63% 17.51% 47.26%  0.00%
# Risk parity            24.80%      13.80%       143.55% 11.44% 12.70%  7.09% 10.35% 14.32% 34.79%  9.30%

# %%
frontier = portfolio.efficient_frontier(quant, symbols, period="3y", n_points=60)
plots.efficient_frontier(frontier).show()

# %%
weights = ms.weights.tolist()
weights
# Out:
# [0.0,
#  4.385228261845348e-16,
#  0.16611372018370743,
#  0.18626612659636044,
#  0.17506236127151925,
#  0.4725577919484126,
#  7.995322325787337e-17]

# %%
quant.portfolio_summary(symbols, weights, period="3y")
# Out:
# {'symbols': ['AAPL', 'MSFT', 'NVDA', 'GOOGL', 'JPM', 'JNJ', 'AMZN'],
#  'weights': [0.0,
#   4.385228261845348e-16,
#   0.16611372018370743,
#   0.18626612659636044,
#   0.17506236127151925,
#   0.4725577919484126,
#   7.995322325787337e-17],
#  'period': '3y',
#  'annualised_return': 0.30867507452910187,
#  'annualised_volatility': 0.1440951416664568,
#  'sharpe_ratio': 1.7951686055305611,
#  'correlation_matrix': {'AAPL': {'AAPL': 1.0,
#    'MSFT': 0.425536022482407,
#    'NVDA': 0.35830397322039087,
#    'GOOGL': 0.4297737067223127,
#    'JPM': 0.31497183207355917,
#    'JNJ': 0.042407690098119386,
#    'AMZN': 0.43728960606599854},
#   'MSFT': {'AAPL': 0.425536022482407,
#    'MSFT': 1.0,
#    'NVDA': 0.5072648451864746,
#    'GOOGL': 0.42120882078240146,
#    'JPM': 0.2693618873189604,
#    'JNJ': -0.12064190960224697,
#    'AMZN': 0.5530724903791544},
#   'NVDA': {'AAPL': 0.35830397322039087,
#    'MSFT': 0.5072648451864746,
#    'NVDA': 1.0,
#    'GOOGL': 0.40545390040366786,
#    'JPM': 0.2704796519599239,
#    'JNJ': -0.24960211567501236,
#    'AMZN': 0.4544231026706502},
#   'GOOGL': {'AAPL': 0.4297737067223127,
#    'MSFT': 0.42120882078240146,
#    'NVDA': 0.40545390040366786,
#    'GOOGL': 1.0,
#    'JPM': 0.26454489306934803,
#    'JNJ': -0.06058501179179981,
#    'AMZN': 0.5460355493257438},
#   'JPM': {'AAPL': 0.31497183207355917,
#    'MSFT': 0.2693618873189604,
#    'NVDA': 0.2704796519599239,
#    'GOOGL': 0.26454489306934803,
#    'JPM': 1.0,
#    'JNJ': 0.11383429369559735,
#    'AMZN': 0.33946128007196547},
#   'JNJ': {'AAPL': 0.042407690098119386,
#    'MSFT': -0.12064190960224697,
#    'NVDA': -0.24960211567501236,
#    'GOOGL': -0.06058501179179981,
#    'JPM': 0.11383429369559735,
#    'JNJ': 1.0,
#    'AMZN': -0.13983889790699625},
#   'AMZN': {'AAPL': 0.43728960606599854,
#    'MSFT': 0.5530724903791544,
#    'NVDA': 0.4544231026706502,
#    'GOOGL': 0.5460355493257438,
#    'JPM': 0.33946128007196547,
#    'JNJ': -0.13983889790699625,
#    'AMZN': 1.0}}}
