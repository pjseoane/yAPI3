# %%
import modules.portfolio as portfolio

from classes.stock_client import StockClient
from classes.quant_analytics import QuantAnalytics as qa
import modules.plots as plots

client = StockClient(ttl_price=60, ttl_info=900)
quant = qa(client)

# %%
symbols = ["AAPL", "MSFT", "NVDA", "GOOGL", "JPM", "JNJ", "AMZN"]

# %%
ew  = portfolio.equal_weight(quant, symbols)
ew
# Out:
# PortfolioResult — Equal weight
#   Return     : 31.04%
#   Volatility : 18.34%
#   Sharpe     : 1.420
#   Weights:
#     AAPL: 14.29%
#     MSFT: 14.29%
#     NVDA: 14.29%
#     GOOGL: 14.29%
#     JPM: 14.29%
#     JNJ: 14.29%
#     AMZN: 14.29%

# %%
mv  = portfolio.min_variance(quant, symbols)
mv
# Out:
# PortfolioResult — Min variance
#   Return     : 19.11%
#   Volatility : 12.12%
#   Sharpe     : 1.164
#   Weights:
#     JNJ: 53.67%
#     MSFT: 19.19%
#     JPM: 13.12%
#     GOOGL: 5.75%
#     AAPL: 4.39%
#     AMZN: 2.16%
#     NVDA: 1.72%

# %%
ms  = portfolio.max_sharpe(quant, symbols)
ms
# Out:
# PortfolioResult — Max Sharpe
#   Return     : 31.62%
#   Volatility : 14.85%
#   Sharpe     : 1.792
#   Weights:
#     JNJ: 43.97%
#     JPM: 19.55%
#     GOOGL: 18.89%
#     NVDA: 17.59%
#     AMZN: 0.00%
#     MSFT: 0.00%
#     AAPL: 0.00%

# %%
rp  = portfolio.risk_parity(quant, symbols)

# %%
# compare all strategies in one table
df = portfolio.compare_strategies(quant, symbols)
print(df.to_string(float_format="{:.2%}".format))
# Out:
#               expected_return  volatility  sharpe_ratio   AAPL   MSFT   NVDA  GOOGL    JPM    JNJ   AMZN
# Equal weight           31.04%      18.34%       141.99% 14.29% 14.29% 14.29% 14.29% 14.29% 14.29% 14.29%
# Min variance           19.11%      12.12%       116.43%  4.39% 19.19%  1.72%  5.75% 13.12% 53.67%  2.16%
# Max Sharpe             31.62%      14.85%       179.24%  0.00%  0.00% 17.59% 18.89% 19.55% 43.97%  0.00%
# Risk parity            24.99%      13.82%       144.56% 11.42% 12.75%  7.11% 10.34% 14.41% 34.63%  9.34%

# %%
frontier = portfolio.efficient_frontier(quant, symbols, period="3y", n_points=60)
plots.efficient_frontier(frontier).show()

# %%
weights = ms.weights.tolist()
weights
# Out:
# [0.0,
#  0.0,
#  0.1758966219083977,
#  0.18889412573786662,
#  0.19550419536753966,
#  0.4397050569861962,
#  4.8417329241878594e-17]

# %%
quant.portfolio_summary(symbols, weights, period="3y")
# Out:
# {'symbols': ['AAPL', 'MSFT', 'NVDA', 'GOOGL', 'JPM', 'JNJ', 'AMZN'],
#  'weights': [0.0,
#   0.0,
#   0.1758966219083977,
#   0.18889412573786662,
#   0.19550419536753966,
#   0.4397050569861962,
#   4.8417329241878594e-17],
#  'period': '3y',
#  'annualised_return': 0.3161896989779643,
#  'annualised_volatility': 0.14850944683778738,
#  'sharpe_ratio': 1.7924092012053325,
#  'correlation_matrix': {'AAPL': {'AAPL': 1.0,
#    'MSFT': 0.4191238648023821,
#    'NVDA': 0.3562078461730878,
#    'GOOGL': 0.43034462236712273,
#    'JPM': 0.31588228024590265,
#    'JNJ': 0.04586903287539139,
#    'AMZN': 0.4355964575217483},
#   'MSFT': {'AAPL': 0.4191238648023821,
#    'MSFT': 1.0,
#    'NVDA': 0.5054692890644404,
#    'GOOGL': 0.42002539038981357,
#    'JPM': 0.26102317227431354,
#    'JNJ': -0.126509002370458,
#    'AMZN': 0.5525383694681615},
#   'NVDA': {'AAPL': 0.3562078461730878,
#    'MSFT': 0.5054692890644404,
#    'NVDA': 1.0,
#    'GOOGL': 0.40674846813753973,
#    'JPM': 0.2669081069281389,
#    'JNJ': -0.2489496185868535,
#    'AMZN': 0.45518469061159617},
#   'GOOGL': {'AAPL': 0.43034462236712273,
#    'MSFT': 0.42002539038981357,
#    'NVDA': 0.40674846813753973,
#    'GOOGL': 1.0,
#    'JPM': 0.2604788848616535,
#    'JNJ': -0.05723517820427169,
#    'AMZN': 0.5475825207524453},
#   'JPM': {'AAPL': 0.31588228024590265,
#    'MSFT': 0.26102317227431354,
#    'NVDA': 0.2669081069281389,
#    'GOOGL': 0.2604788848616535,
#    'JPM': 1.0,
#    'JNJ': 0.11535886162497368,
#    'AMZN': 0.33303870735894303},
#   'JNJ': {'AAPL': 0.04586903287539139,
#    'MSFT': -0.126509002370458,
#    'NVDA': -0.2489496185868535,
#    'GOOGL': -0.05723517820427169,
#    'JPM': 0.11535886162497368,
#    'JNJ': 1.0,
#    'AMZN': -0.1397738651717463},
#   'AMZN': {'AAPL': 0.4355964575217483,
#    'MSFT': 0.5525383694681615,
#    'NVDA': 0.45518469061159617,
#    'GOOGL': 0.5475825207524453,
#    'JPM': 0.33303870735894303,
#    'JNJ': -0.1397738651717463,
#    'AMZN': 1.0}}}
