# %%
import yfinance_api3.modules.portfolio as portfolio

from yfinance_api3.classes.stock_client import StockClient
from yfinance_api3.classes.quant_analytics import QuantAnalytics as qa
import yfinance_api3.modules.plots as plots

client = StockClient(ttl_price=60, ttl_info=900)
quant = qa(client)

# %%
symbols = ["AAPL", "MSFT", "NVDA", "GOOGL", "JPM", "JNJ", "AMZN"]

# %%
ew  = portfolio.equal_weight(quant, symbols)
ew
# Out:
# PortfolioResult — Equal weight
#   Return     : 31.04%
#   Volatility : 18.34%
#   Sharpe     : 1.420
#   Weights:
#     AAPL: 14.29%
#     MSFT: 14.29%
#     NVDA: 14.29%
#     GOOGL: 14.29%
#     JPM: 14.29%
#     JNJ: 14.29%
#     AMZN: 14.29%

# %%
mv  = portfolio.min_variance(quant, symbols)
mv
# Out:
# PortfolioResult — Min variance
#   Return     : 19.11%
#   Volatility : 12.12%
#   Sharpe     : 1.164
#   Weights:
#     JNJ: 53.67%
#     MSFT: 19.19%
#     JPM: 13.12%
#     GOOGL: 5.75%
#     AAPL: 4.39%
#     AMZN: 2.16%
#     NVDA: 1.72%

# %%
ms  = portfolio.max_sharpe(quant, symbols)
ms
# Out:
# PortfolioResult — Max Sharpe
#   Return     : 31.62%
#   Volatility : 14.85%
#   Sharpe     : 1.792
#   Weights:
#     JNJ: 43.97%
#     JPM: 19.55%
#     GOOGL: 18.89%
#     NVDA: 17.59%
#     AAPL: 0.00%
#     MSFT: 0.00%
#     AMZN: 0.00%

# %%
rp  = portfolio.risk_parity(quant, symbols)

# %%
# compare all strategies in one table
df = portfolio.compare_strategies(quant, symbols)
print(df.to_string(float_format="{:.2%}".format))
# Out:
#               expected_return  volatility  sharpe_ratio   AAPL   MSFT   NVDA  GOOGL    JPM    JNJ   AMZN
# Equal weight           31.04%      18.34%       141.99% 14.29% 14.29% 14.29% 14.29% 14.29% 14.29% 14.29%
# Min variance           19.11%      12.12%       116.43%  4.39% 19.19%  1.72%  5.75% 13.12% 53.67%  2.16%
# Max Sharpe             31.62%      14.85%       179.24%  0.00%  0.00% 17.59% 18.89% 19.55% 43.97%  0.00%
# Risk parity            24.99%      13.82%       144.56% 11.42% 12.75%  7.11% 10.34% 14.41% 34.63%  9.34%

# %%
frontier = portfolio.efficient_frontier(quant, symbols, period="3y", n_points=60)
plots.efficient_frontier(frontier).show()

# %%
weights = ms.weights.tolist()
weights
# Out:
# [9.818519566193703e-17,
#  6.964928531650253e-17,
#  0.17589653838951103,
#  0.18889418464534113,
#  0.19550432357123512,
#  0.43970495339391263,
#  0.0]

# %%
quant.portfolio_summary(symbols, weights, period="3y")
# Out:
# {'symbols': ['AAPL', 'MSFT', 'NVDA', 'GOOGL', 'JPM', 'JNJ', 'AMZN'],
#  'weights': [9.818519566193703e-17,
#   6.964928531650253e-17,
#   0.17589653838951103,
#   0.18889418464534113,
#   0.19550432357123512,
#   0.43970495339391263,
#   0.0],
#  'period': '3y',
#  'annualised_return': 0.31618974796082994,
#  'annualised_volatility': 0.14850947870618172,
#  'sharpe_ratio': 1.7924091464052103,
#  'correlation_matrix': {'AAPL': {'AAPL': 1.0,
#    'MSFT': 0.41912396157696685,
#    'NVDA': 0.3562078435791257,
#    'GOOGL': 0.43034467089371276,
#    'JPM': 0.3158821655463815,
#    'JNJ': 0.0458691963845227,
#    'AMZN': 0.43559666551303067},
#   'MSFT': {'AAPL': 0.41912396157696685,
#    'MSFT': 1.0,
#    'NVDA': 0.5054687566156632,
#    'GOOGL': 0.4200253652913948,
#    'JPM': 0.26102324356469586,
#    'JNJ': -0.12650792752729498,
#    'AMZN': 0.5525380737077986},
#   'NVDA': {'AAPL': 0.3562078435791257,
#    'MSFT': 0.5054687566156632,
#    'NVDA': 1.0,
#    'GOOGL': 0.4067485002173933,
#    'JPM': 0.2669080894516928,
#    'JNJ': -0.2489490228686368,
#    'AMZN': 0.4551846469180732},
#   'GOOGL': {'AAPL': 0.43034467089371276,
#    'MSFT': 0.4200253652913948,
#    'NVDA': 0.4067485002173933,
#    'GOOGL': 1.0,
#    'JPM': 0.26047870634089837,
#    'JNJ': -0.05723495542616383,
#    'AMZN': 0.5475826163885521},
#   'JPM': {'AAPL': 0.3158821655463815,
#    'MSFT': 0.26102324356469586,
#    'NVDA': 0.2669080894516928,
#    'GOOGL': 0.26047870634089837,
#    'JPM': 1.0,
#    'JNJ': 0.11535976912273688,
#    'AMZN': 0.33303909494173656},
#   'JNJ': {'AAPL': 0.0458691963845227,
#    'MSFT': -0.12650792752729498,
#    'NVDA': -0.2489490228686368,
#    'GOOGL': -0.05723495542616383,
#    'JPM': 0.11535976912273688,
#    'JNJ': 1.0,
#    'AMZN': -0.13977343237698883},
#   'AMZN': {'AAPL': 0.43559666551303067,
#    'MSFT': 0.5525380737077986,
#    'NVDA': 0.4551846469180732,
#    'GOOGL': 0.5475826163885521,
#    'JPM': 0.33303909494173656,
#    'JNJ': -0.13977343237698883,
#    'AMZN': 1.0}}}
