# %%
import modules.portfolio as portfolio

from classes.stock_client import StockClient
from classes.quant_analytics import QuantAnalytics as qa
import modules.plots as plots

client = StockClient(ttl_price=60, ttl_info=900)
quant = qa(client)

# %%
symbols = ["AAPL", "MSFT", "NVDA", "GOOGL", "JPM", "JNJ", "AMZN"]

# %%
ew  = portfolio.equal_weight(quant, symbols)
ew
# Out:
# PortfolioResult — Equal weight
#   Return     : 31.04%
#   Volatility : 18.34%
#   Sharpe     : 1.420
#   Weights:
#     AAPL: 14.29%
#     MSFT: 14.29%
#     NVDA: 14.29%
#     GOOGL: 14.29%
#     JPM: 14.29%
#     JNJ: 14.29%
#     AMZN: 14.29%

# %%
mv  = portfolio.min_variance(quant, symbols)
mv
# Out:
# PortfolioResult — Min variance
#   Return     : 19.11%
#   Volatility : 12.12%
#   Sharpe     : 1.164
#   Weights:
#     JNJ: 53.67%
#     MSFT: 19.19%
#     JPM: 13.12%
#     GOOGL: 5.75%
#     AAPL: 4.39%
#     AMZN: 2.16%
#     NVDA: 1.72%

# %%
ms  = portfolio.max_sharpe(quant, symbols)
ms
# Out:
# PortfolioResult — Max Sharpe
#   Return     : 31.62%
#   Volatility : 14.85%
#   Sharpe     : 1.792
#   Weights:
#     JNJ: 43.97%
#     JPM: 19.55%
#     GOOGL: 18.89%
#     NVDA: 17.59%
#     AAPL: 0.00%
#     MSFT: 0.00%
#     AMZN: 0.00%

# %%
rp  = portfolio.risk_parity(quant, symbols)

# %%
# compare all strategies in one table
df = portfolio.compare_strategies(quant, symbols)
print(df.to_string(float_format="{:.2%}".format))
# Out:
#               expected_return  volatility  sharpe_ratio   AAPL   MSFT   NVDA  GOOGL    JPM    JNJ   AMZN
# Equal weight           31.04%      18.34%       141.99% 14.29% 14.29% 14.29% 14.29% 14.29% 14.29% 14.29%
# Min variance           19.11%      12.12%       116.43%  4.39% 19.19%  1.72%  5.75% 13.12% 53.67%  2.16%
# Max Sharpe             31.62%      14.85%       179.24%  0.00%  0.00% 17.59% 18.89% 19.55% 43.97%  0.00%
# Risk parity            24.99%      13.82%       144.56% 11.42% 12.75%  7.11% 10.34% 14.41% 34.63%  9.34%

# %%
frontier = portfolio.efficient_frontier(quant, symbols, period="3y", n_points=60)
plots.efficient_frontier(frontier).show()

# %%
weights = ms.weights.tolist()
weights
# Out:
# [7.15263077187894e-17,
#  2.4270183885697467e-17,
#  0.17589654683525124,
#  0.18889426071632082,
#  0.19550427540847298,
#  0.4397049170399548,
#  0.0]

# %%
quant.portfolio_summary(symbols, weights, period="3y")
# Out:
# {'symbols': ['AAPL', 'MSFT', 'NVDA', 'GOOGL', 'JPM', 'JNJ', 'AMZN'],
#  'weights': [7.15263077187894e-17,
#   2.4270183885697467e-17,
#   0.17589654683525124,
#   0.18889426071632082,
#   0.19550427540847298,
#   0.4397049170399548,
#   0.0],
#  'period': '3y',
#  'annualised_return': 0.31618970878045843,
#  'annualised_volatility': 0.14850951343076824,
#  'sharpe_ratio': 1.7924084634790083,
#  'correlation_matrix': {'AAPL': {'AAPL': 1.0,
#    'MSFT': 0.41912385232256966,
#    'NVDA': 0.3562077157328061,
#    'GOOGL': 0.4303448414029728,
#    'JPM': 0.3158824483568304,
#    'JNJ': 0.04586922681564173,
#    'AMZN': 0.4355964419339107},
#   'MSFT': {'AAPL': 0.41912385232256966,
#    'MSFT': 1.0,
#    'NVDA': 0.5054687338356176,
#    'GOOGL': 0.4200252933810583,
#    'JPM': 0.2610231820227051,
#    'JNJ': -0.1265087082997539,
#    'AMZN': 0.5525383139817867},
#   'NVDA': {'AAPL': 0.3562077157328061,
#    'MSFT': 0.5054687338356176,
#    'NVDA': 1.0,
#    'GOOGL': 0.4067486692032967,
#    'JPM': 0.26690840968374596,
#    'JNJ': -0.24894857560750688,
#    'AMZN': 0.45518467194190076},
#   'GOOGL': {'AAPL': 0.4303448414029728,
#    'MSFT': 0.4200252933810583,
#    'NVDA': 0.4067486692032967,
#    'GOOGL': 1.0,
#    'JPM': 0.2604789178085885,
#    'JNJ': -0.05723488116989394,
#    'AMZN': 0.5475827595806031},
#   'JPM': {'AAPL': 0.3158824483568304,
#    'MSFT': 0.2610231820227051,
#    'NVDA': 0.26690840968374596,
#    'GOOGL': 0.2604789178085885,
#    'JPM': 1.0,
#    'JNJ': 0.11535952170470688,
#    'AMZN': 0.333039276634667},
#   'JNJ': {'AAPL': 0.04586922681564173,
#    'MSFT': -0.1265087082997539,
#    'NVDA': -0.24894857560750688,
#    'GOOGL': -0.05723488116989394,
#    'JPM': 0.11535952170470688,
#    'JNJ': 1.0,
#    'AMZN': -0.13977365996315674},
#   'AMZN': {'AAPL': 0.4355964419339107,
#    'MSFT': 0.5525383139817867,
#    'NVDA': 0.45518467194190076,
#    'GOOGL': 0.5475827595806031,
#    'JPM': 0.333039276634667,
#    'JNJ': -0.13977365996315674,
#    'AMZN': 1.0}}}
