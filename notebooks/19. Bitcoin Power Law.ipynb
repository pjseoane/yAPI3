# %%
from yfinance_api3.modules.powerlaw import PowerLaw
import yfinance_api3.modules.plots as plots

# fit the model
pl = PowerLaw(corridor_low=10, corridor_high=90)
pl.fit()

# summary
print(pl.summary())

# current position
pos = pl.current_position()
print(f"\nPhase: {pos['phase']}")
print(f"Position in corridor: {pos['corridor_pct']:.1%}")

# fair value projections
print(pl.fair_value("2025-12-31"))
print(pl.fair_value("2028-01-01"))

# cycle peaks/troughs
print(pl.cycle_analysis())

# plots
plots.powerlaw_chart(pl).show()
plots.powerlaw_residuals(pl).show()
plots.powerlaw_forecast(pl, years=4).show()
# Out:
# Bitcoin Power Law Model
# ==================================================
#   Formula : log(P) = -39.8333 + 5.8995 × log(days)
#   R²      : 0.9207  (N=4,247)
#   Fit date: 2026-05-03
#
# Current Position
# --------------------------------------------------
#   Price       : $      78,404
#   Floor       : $      73,756
#   Model       : $     133,811
#   Median      : $     117,953
#   Ceiling     : $     296,046
#   Position    : 4.3% of corridor
#   Phase       : floor zone
#   Next halving: 717 days
#
# Fair Value Projections
# --------------------------------------------------
#   +1 year  floor/model/ceiling: $   102,672 / $   186,272 / $   412,111
#   +4 years floor/model/ceiling: $   250,965 / $   455,314 / $ 1,007,341
#
# Phase: floor zone
# Position in corridor: 4.3%
# {'date': '2025-12-31', 'days': 6206, 'model_price': np.float64(119181.67), 'floor_price': np.float64(65691.98), 'median_price': np.float64(105057.4), 'ceiling_price': np.float64(263678.96)}
# {'date': '2028-01-01', 'days': 6937, 'model_price': np.float64(229883.48), 'floor_price': np.float64(126709.92), 'median_price': np.float64(202639.9), 'ceiling_price': np.float64(508596.97)}
#          date          price  residual  corridor_pct    type
# 0  2015-01-14     178.102997 -0.393295      0.145621  trough
# 1  2015-08-24     210.494995 -0.792858     -0.141885  trough
# 2  2015-12-15     465.321014 -0.268392      0.235495    peak
# 3  2016-05-22     439.322998 -0.684495     -0.063913  trough
# 4  2016-06-16     766.307983 -0.182600      0.297227    peak
# 5  2017-01-11     777.757019 -0.604349     -0.006243  trough
# 6  2017-06-11    2958.110107  0.435084      0.741682    peak
# 7  2017-07-16    1929.819946 -0.058680      0.386393  trough
# 8  2017-12-16   19497.400391  1.971389      1.847131    peak
# 9  2018-02-05    6955.270020  0.849280      1.039717  trough
# 10 2018-07-24    8424.269531  0.747985      0.966830    peak
# 11 2019-02-07    3399.471680 -0.485150      0.079526  trough
# 12 2019-06-26   13016.231445  0.639106      0.888486    peak
# 13 2020-02-12   10326.054688  0.061729      0.473034    peak
# 14 2020-03-12    4970.788086 -0.711383     -0.083260  trough
# 15 2021-03-13   61243.085938  1.293791      1.359565    peak
# 16 2021-07-20   29807.347656  0.405183      0.720166  trough
# 17 2021-10-20   65992.835938  1.082669      1.207652    peak
# 18 2022-11-21   15787.284180 -0.828713     -0.167685  trough
# 19 2023-04-14   30485.699219 -0.335884      0.186931    peak
# 20 2023-09-11   25162.654297 -0.695105     -0.071547  trough
# 21 2024-03-13   73083.500000  0.172162      0.552496    peak
# 22 2024-09-06   53948.753906 -0.316680      0.200749  trough
# 23 2024-12-17  106140.601562  0.255867      0.612726    peak
# 24 2025-04-08   76271.953125 -0.186909      0.294126  trough
# 25 2025-07-14  119849.703125  0.169448      0.550543    peak
