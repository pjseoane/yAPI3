# %%
from modules import backtest, plots
from classes.stock_client import StockClient
from classes.quant_analytics import QuantAnalytics as qa

# %%
client = StockClient(ttl_price=60, ttl_info=900)
quant = qa(client)

# %%
symbols = ["AAPL", "MSFT", "NVDA", "GOOGL", "JPM"]

# %%
# run a strategy
result = backtest.run(quant, symbols,
    strategy=backtest.ma_crossover(fast=20, slow=50),
    period="3y",
    rebalance="monthly",
    transaction_cost_bps=10,
    benchmark="SPY")

print(result)                   # readable summary
print(result.metrics_df())      # vs benchmark table

plots.backtest(result).show()
# Out:
# BacktestResult — MA Crossover (20/50)
#   Period       : 3y
#   CAGR         : 18.57%
#   Volatility   : 19.19%
#   Sharpe       : 0.724
#   Max Drawdown : -25.06%
#   Calmar       : 0.741
#   # Trades     : 25
#   Total costs  : 2.33%
#
#   Benchmark (SPY)
#   CAGR         : 21.43%
#   Sharpe       : 1.023
#   Max Drawdown : -18.76%
#               MA Crossover (20/50)      SPY
# cagr                        18.57%   21.43%
# total_return                66.26%   78.49%
# volatility                  19.19%   15.22%
# sharpe_ratio                72.38%  102.29%
# sortino_ratio               95.88%  136.93%
# max_drawdown               -25.06%  -18.76%
# calmar_ratio                74.13%  114.25%
# n_trades                        25        1
# total_cost                   2.33%    0.00%
# best_day                     5.26%   10.50%
# worst_day                   -9.51%   -5.85%
# win_rate                    45.74%   57.05%

# %%
from modules import backtest, plots

mag7 = ["AAPL", "MSFT", "NVDA", "GOOGL", "META", "AMZN", "TSLA"]

result = backtest.run(
    quant, mag7,
    strategy=backtest.buy_and_hold(),   # equal weight, no rebalancing cost
    period="3y",
    rebalance="monthly",                # rebalance back to equal weight monthly
    transaction_cost_bps=5,
    benchmark="SPY",
)

print(result)                           # CAGR, Sharpe, Max DD vs SPY
print(result.metrics_df())              # side-by-side table
plots.backtest(result).show()           # equity curve + drawdown panel
# Out:
# BacktestResult — Buy & Hold
#   Period       : 3y
#   CAGR         : 45.03%
#   Volatility   : 26.05%
#   Sharpe       : 1.365
#   Max Drawdown : -28.99%
#   Calmar       : 1.554
#   # Trades     : 1
#   Total costs  : 0.05%
#
#   Benchmark (SPY)
#   CAGR         : 21.43%
#   Sharpe       : 1.023
#   Max Drawdown : -18.76%
#               Buy & Hold      SPY
# cagr              45.03%   21.43%
# total_return     203.27%   78.49%
# volatility        26.05%   15.22%
# sharpe_ratio     136.54%  102.29%
# sortino_ratio    202.01%  136.93%
# max_drawdown     -28.99%  -18.76%
# calmar_ratio     155.36%  114.25%
# n_trades               1        1
# total_cost         0.05%    0.00%
# best_day          14.76%   10.50%
# worst_day         -6.69%   -5.85%
# win_rate          54.92%   57.05%

# %%
plots.backtest(result).show()
