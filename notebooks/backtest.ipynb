# %%
from modules import backtest, plots
from classes.stock_client import StockClient
from classes.quant_analytics import QuantAnalytics as qa

# %%
client = StockClient(ttl_price=60, ttl_info=900)
quant = qa(client)

# %%
symbols = ["AAPL", "MSFT", "NVDA", "GOOGL", "JPM"]

# %%
# run a strategy
result = backtest.run(quant, symbols,
    strategy=backtest.ma_crossover(fast=20, slow=50),
    period="3y",
    rebalance="monthly",
    transaction_cost_bps=10,
    benchmark="SPY")

print(result)                   # readable summary
print(result.metrics_df())      # vs benchmark table

plots.backtest(result).show()
# Out:
# BacktestResult — MA Crossover (20/50)
#   Period       : 3y
#   CAGR         : 16.25%
#   Volatility   : 19.03%
#   Sharpe       : 0.624
#   Max Drawdown : -25.06%
#   Calmar       : 0.648
#   # Trades     : 25
#   Total costs  : 2.33%
#
#   Benchmark (SPY)
#   CAGR         : 21.50%
#   Sharpe       : 1.026
#   Max Drawdown : -18.76%
#               MA Crossover (20/50)      SPY
# cagr                        16.25%   21.50%
# total_return                56.62%   78.67%
# volatility                  19.03%   15.23%
# sharpe_ratio                62.41%  102.63%
# sortino_ratio               82.23%  137.42%
# max_drawdown               -25.06%  -18.76%
# calmar_ratio                64.84%  114.64%
# n_trades                        25        1
# total_cost                   2.33%    0.00%
# best_day                     5.26%   10.50%
# worst_day                   -9.51%   -5.85%
# win_rate                    44.21%   56.99%

# %%
from modules import backtest, plots

mag7 = ["AAPL", "MSFT", "NVDA", "GOOGL", "META", "AMZN", "TSLA"]

result = backtest.run(
    quant, mag7,
    strategy=backtest.buy_and_hold(),   # equal weight, no rebalancing cost
    period="6mo",
    rebalance="monthly",                # rebalance back to equal weight monthly
    transaction_cost_bps=5,
    benchmark="SPY",
)

print(result)                           # CAGR, Sharpe, Max DD vs SPY
print(result.metrics_df())              # side-by-side table
plots.backtest(result).show()           # equity curve + drawdown panel
# Out:
# BacktestResult — Buy & Hold
#   Period       : 6mo
#   CAGR         : 6.51%
#   Volatility   : 21.76%
#   Sharpe       : 0.168
#   Max Drawdown : -17.71%
#   Calmar       : 0.368
#   # Trades     : 1
#   Total costs  : 0.05%
#
#   Benchmark (SPY)
#   CAGR         : 12.84%
#   Sharpe       : 0.596
#   Max Drawdown : -8.88%
#               Buy & Hold      SPY
# cagr               6.51%   12.84%
# total_return       3.18%    6.18%
# volatility        21.76%   13.38%
# sharpe_ratio      16.80%   59.58%
# sortino_ratio     26.16%   88.74%
# max_drawdown     -17.71%   -8.88%
# calmar_ratio      36.77%  144.52%
# n_trades               1        1
# total_cost         0.05%    0.00%
# best_day           4.53%    2.91%
# worst_day         -3.20%   -2.04%
# win_rate          52.00%   54.40%

# %%
plots.backtest(result).show()

# %%
result = backtest.run(quant, mag7, strategy=backtest.buy_and_hold(), period="1y")
print(type(result.equity_curve.index))
print(repr(result.equity_curve.index[:3]))
print(result.equity_curve.head(3))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
# DatetimeIndex(['2025-04-21', '2025-04-22', '2025-04-23'], dtype='datetime64[ns]', name='date', freq=None)
# date
# 2025-04-21    100000.000000
# 2025-04-22    102967.556477
# 2025-04-23    106581.401861
# dtype: float64
